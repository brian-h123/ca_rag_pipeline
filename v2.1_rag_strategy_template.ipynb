# %% [markdown]
# # V2.1 RAG with Strategy Template
# Testing the effects of model temperature and other possible factors on LLM output generation.
#
# One of the key issue identified in V2.1 is the variability of output generated by the LLM. As displayed in the sample output in folder `v2.0_sample_output`, the code generated by the LLM model and even the retriever results can change, given the same ingested data and text splitting specification.
#
# Hence, in this version, the focus will be on investigating factors that affects LLM output randomness and how to stabilize them.
#
# We will use the arguments: \
# ```chunk_size = 2000``` \
# ```chunk_overlap = 500```\
# for the text splitter as it was tested and believed to be the better performing set of values from `v2.0_rag_strategy_template`.

# %% [markdown]
# ## Takeaways
# https://medium.com/@prabhavithreddy/controlling-creativity-how-to-get-reproducible-outcomes-from-llms-016ec0991891
#
# 1. Model Temperature
#     - Setting temperature = 0 achieves the best effect on generating outputs that are similar and determinant.
#     - The code generated by ```temperature=0``` are almost identical, while the code explanation can vary across responses.
# 2. Seed
#     - Setting a specific does not show obvious effects on improving reproducibility. Moreover, it is hard to define which seed is better.
#     - Rather than spending time identifying the "optimal" seed, we should spend time on enhancing other components of the pipeline for better performance.

# %%
# %pip install --user -qU langchain
# %pip install --user -qU langchain_community
# %pip install --user -qU langchain_chroma
# %pip install --user -qU langchain-openai
# %pip install --user -qU langchainhub
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Model Temperature
# Configuring the model temperature is one of the first we can do to control the randomness of LLM responses.
#
# The default temperature set for the OpenAI gpt3.5 is 0.7. This configuration was used in previous versions.
#
# For this section, we will be reusing the same system prompt and vector store (same embeddings)

# %%
import os
import getpass

os.environ['OPENAI_API_KEY'] = getpass.getpass()

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_community.document_loaders import PythonLoader
from langchain_text_splitters import ( Language, RecursiveCharacterTextSplitter)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# ### Temperature = 0.7 (default)

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0.7)

# %%
folder_path = "strategy-template"

documents = []
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        loader = PythonLoader(file_path)
        loaded_docs = loader.load()
        # Add source metadata to each document
        for doc in loaded_docs:
            doc.metadata["source"] = filename
        documents.extend(loaded_docs)

# %%
print(documents[0])
# Out:
# page_content='class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.subscribed_books = {}
#         self.period = 45 * 60
#         self.options = {}
#
#         self.divide_quote = 0
#         self.proportion = 0.2
#         self.aroon_period = 14
#
#     def on_order_state_change(self,  order):
#         pass
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#         high_price_history = [candle['high'] for candle in candles[exchange][pair]]
#         low_price_history = [candle['low'] for candle in candles[exchange][pair]]
#         open_price_history = [candle['open'] for candle in candles[exchange][pair]]
#
#         # convert to chronological order for talib
#         close_price_history.reverse()
#         high_price_history.reverse()
#         low_price_history.reverse()
#         open_price_history.reverse()
#
#         # convert to np.array
#         close_price_history = np.array(close_price_history)
#         high_price_history = np.array(high_price_history)
#         low_price_history = np.array(low_price_history)
#         open_price_history = np.array(open_price_history)
#
#         close_price = close_price_history[-1]
#         high_price = high_price_history[-1]
#
#         # get available balance
#         base_balance = CA.get_balance(exchange, base)
#         quote_balance = CA.get_balance(exchange, quote)
#         available_base_amount = base_balance.available
#         available_quote_amount = quote_balance.available
#
#         if self.divide_quote == 0:
#             self.divide_quote = np.round(available_quote_amount* self.proportion, 5)
#
#         aroondown, aroonup = talib.AROON(high_price_history, low_price_history, timeperiod=self.aroon_period)
#         aroon_down = aroondown[-1]
#         aroon_up = aroonup[-1]
#
#         signal = 0
#         # Aroon-Up above 50 and Aroon-Up larger than Aroon-Down mean the market is bullish
#         if aroon_up > 50 and aroon_up > aroon_down:
#             signal = 1
#
#         # Aroon-Down above 50 and Aroon-Dwon larger than Aroon-Up mean the market is bearish
#         elif aroon_down > 50 and aroon_down > aroon_up:
#             signal = -1
#
#         # place buy order
#         if signal == 1:
#             amount = self.divide_quote/high_price
#             if available_quote_amount >= amount * close_price:
#                 CA.log('Buy ' + base)
#                 CA.buy(exchange, pair, amount, CA.OrderType.MARKET)
#
#         # place sell order
#         elif signal == -1:
#             if available_base_amount > 0.00001:
#                 self.divide_quote = 0
#                 CA.log('Sell ' + base)
#                 CA.sell(exchange, pair, available_base_amount, CA.OrderType.MARKET)
#         return
# ' metadata={'source': 'Aroon-en.py'}

# %%
text_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, 
    chunk_size=2000, 
    chunk_overlap=500,
    length_function=len,
    add_start_index=True
)
text_chunks = text_splitter.split_documents(documents)

# %%
# View the chunks that has the source of 'RSI-en.py'
rsi_chunks = [chunk for chunk in text_chunks if chunk.metadata['source'] == 'RSI-en.py']
for chunk in rsi_chunks:
    print(chunk.metadata)
# Out:
# {'source': 'RSI-en.py', 'start_index': 0}
# {'source': 'RSI-en.py', 'start_index': 1302}
# {'source': 'RSI-en.py', 'start_index': 2626}
# {'source': 'RSI-en.py', 'start_index': 4201}

# %%
vectorstore = Chroma.from_documents(documents=text_chunks, embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()

# %%
system_prompt = (
    """
    You are a coding assistant with expertise in Crypto Arsenal's documentation.Here is a set of Crypto Arsenal's documentation retrieved to answer the question: \n -------- \n {context} \n -------- \n Ensure any code you provide can be executed with all the required imports and variables defined. If you do not know the answer or require further clarification, just say that you do not know.
    """
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response_1 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_1["answer"])
# Out:
# To create a strategy where you buy Bitcoin if its RSI drops below 30 and sell if it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the modified code snippet for your strategy:
#
# ```python
# class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.short_period = 14  # RSI short period
#         self.long_period = 28  # RSI long period
#         self.proportion = 0.2  # Proportion for trade amount
#         self.rsi_lower_band = 30  # RSI lower band for buying
#         self.rsi_upper_band = 70  # RSI upper band for selling
#         self.trade_amount = 0  # Amount to trade
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         if len(close_price_history) < self.long_period + 1:
#             return []
#
#         # current RSI values
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         # Check RSI conditions for buying and selling
#         if curr_rsi_short < self.rsi_lower_band and curr_rsi_long < self.rsi_lower_band:
#             # Buy Bitcoin
#             self.trade_amount = 1  # Set the amount to buy
#             CA.log('Buy Bitcoin when RSI is below 30')
#
#         elif curr_rsi_short > self.rsi_upper_band and curr_rsi_long > self.rsi_upper_band:
#             # Sell Bitcoin
#             self.trade_amount = -1  # Set the amount to sell
#             CA.log('Sell Bitcoin when RSI is above 70')
#
#         # Execute the trade based on the trade_amount
#         if self.trade_amount != 0:
#             return [
#                 {
#                     'exchange': exchange,
#                     'amount': self.trade_amount,
#                     'price': -1,  # Market order
#                     'type': 'MARKET',
#                     'pair': pair,
#                     'margin': True,
#                 }
#             ]
#         else:
#             return []
# ```
#
# Please note that this is a simplified version of the modified code snippet based on your requirements. You may need to adjust the code further based on your specific trading platform and additional logic.

# %%
for document in response_1["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_2 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_2["answer"])
# Out:
# To create a strategy where you buy Bitcoin if its RSI drops below 30 and sell if it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version that focuses on the buying and selling based on RSI levels:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.rsi_period = 14
#         self.rsi_upper_threshold = 70
#         self.rsi_lower_threshold = 30
#         self.in_position = False
#
#     def trade(self, close_price_history):
#         rsi = talib.RSI(np.array(close_price_history), timeperiod=self.rsi_period)
#         curr_rsi = rsi[-1]
#
#         signal = 0
#         if curr_rsi < self.rsi_lower_threshold and not self.in_position:
#             signal = 1  # Buy signal
#             self.in_position = True
#         elif curr_rsi > self.rsi_upper_threshold and self.in_position:
#             signal = -1  # Sell signal
#             self.in_position = False
#
#         return signal
#
# # Example of how to use the RsiStrategy class
# strategy = RsiStrategy()
# close_prices = [100, 110, 120, 130, 140, 150, 160]  # Example close price history
# for i in range(len(close_prices)):
#     signal = strategy.trade(close_prices[:i+1])
#     if signal == 1:
#         print(f"Buy Bitcoin at price: {close_prices[i]}")
#     elif signal == -1:
#         print(f"Sell Bitcoin at price: {close_prices[i]}")
# ```
#
# In this code snippet:
# - The `RsiStrategy` class initializes the RSI period, upper and lower RSI thresholds, and a boolean flag to track whether the strategy is currently in a position.
# - The `trade` method calculates the RSI using `talib.RSI` and determines whether to buy (signal = 1) if RSI drops below 30 and not already in a position, or sell (signal = -1) if RSI goes above 70 and currently in a position.
# - You can create an instance of the `RsiStrategy` class and call the `trade` method with a list of close prices to simulate buying and selling based on RSI levels.
#
# Please note that this is a simplified strategy implementation. You may need to integrate this logic into your existing trading system for actual trading execution.

# %%
for document in response_2["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_3 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_3["answer"])
# Out:
# To create a strategy where you buy Bitcoin if its Relative Strength Index (RSI) drops below 30 and sell if it goes above 70, you can modify the existing code snippet provided from Crypto Arsenal's documentation. Here's an outline of the modifications you can make:
#
# 1. Update the RSI upper and lower bands to 70 and 30 respectively.
# 2. Adjust the signal logic to buy when RSI drops below 30 and sell when it goes above 70.
#
# Here is the modified code snippet based on the existing code structure:
#
# ```python
# class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.subscribed_books = {}
#         self.period = 30 * 60
#         self.options = {}
#
#         self.last_type = 'sell'
#         self.short_period = 5
#         self.long_period = 10
#         self.divide_quote = 0
#         self.proportion = 0.2
#
#         self.rsi_upper_band = 70  # Updated upper RSI band to 70
#         self.rsi_lower_band = 30  # Updated lower RSI band to 30
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#
#         rsi_short = talib.RSI(close_price_history, self.short_period)
#         rsi_long = talib.RSI(close_price_history, self.long_period)
#
#         if len(close_price_history) < self.long_period + 1:
#             return []
#
#         # current rsi, short and long period respectively
#         curr_rsi_short = rsi_short[-1]
#
#         # Buy if RSI drops below 30
#         if curr_rsi_short < self.rsi_lower_band:
#             signal = 1  # Signal to buy
#
#         # Sell if RSI goes above 70
#         elif curr_rsi_short > self.rsi_upper_band:
#             signal = 2  # Signal to sell
#
#         # Place buy or sell order based on the signal
#         if signal == 1:
#             # Place buy order logic here
#             CA.log('Buy Bitcoin')
#             # Implement the buy logic based on your trading platform
#
#         elif signal == 2:
#             # Place sell order logic here
#             CA.log('Sell Bitcoin')
#             # Implement the sell logic based on your trading platform
# ```
#
# This modification will trigger a buy signal when the RSI drops below 30 and a sell signal when it goes above 70. You can integrate this updated code into your trading strategy to execute buy and sell orders based on the RSI levels of Bitcoin.

# %%
for document in response_3["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %% [markdown]
# ### Temperature = 0.4

# %%
# Reseting Chroma vectorstore collection
vectorstore.reset_collection()

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0.4)

# %%
folder_path = "strategy-template"

documents = []
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        loader = PythonLoader(file_path)
        loaded_docs = loader.load()
        # Add source metadata to each document
        for doc in loaded_docs:
            doc.metadata["source"] = filename
        documents.extend(loaded_docs)

# %%
print(documents[0])
# Out:
# page_content='class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.subscribed_books = {}
#         self.period = 45 * 60
#         self.options = {}
#
#         self.divide_quote = 0
#         self.proportion = 0.2
#         self.aroon_period = 14
#
#     def on_order_state_change(self,  order):
#         pass
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#         high_price_history = [candle['high'] for candle in candles[exchange][pair]]
#         low_price_history = [candle['low'] for candle in candles[exchange][pair]]
#         open_price_history = [candle['open'] for candle in candles[exchange][pair]]
#
#         # convert to chronological order for talib
#         close_price_history.reverse()
#         high_price_history.reverse()
#         low_price_history.reverse()
#         open_price_history.reverse()
#
#         # convert to np.array
#         close_price_history = np.array(close_price_history)
#         high_price_history = np.array(high_price_history)
#         low_price_history = np.array(low_price_history)
#         open_price_history = np.array(open_price_history)
#
#         close_price = close_price_history[-1]
#         high_price = high_price_history[-1]
#
#         # get available balance
#         base_balance = CA.get_balance(exchange, base)
#         quote_balance = CA.get_balance(exchange, quote)
#         available_base_amount = base_balance.available
#         available_quote_amount = quote_balance.available
#
#         if self.divide_quote == 0:
#             self.divide_quote = np.round(available_quote_amount* self.proportion, 5)
#
#         aroondown, aroonup = talib.AROON(high_price_history, low_price_history, timeperiod=self.aroon_period)
#         aroon_down = aroondown[-1]
#         aroon_up = aroonup[-1]
#
#         signal = 0
#         # Aroon-Up above 50 and Aroon-Up larger than Aroon-Down mean the market is bullish
#         if aroon_up > 50 and aroon_up > aroon_down:
#             signal = 1
#
#         # Aroon-Down above 50 and Aroon-Dwon larger than Aroon-Up mean the market is bearish
#         elif aroon_down > 50 and aroon_down > aroon_up:
#             signal = -1
#
#         # place buy order
#         if signal == 1:
#             amount = self.divide_quote/high_price
#             if available_quote_amount >= amount * close_price:
#                 CA.log('Buy ' + base)
#                 CA.buy(exchange, pair, amount, CA.OrderType.MARKET)
#
#         # place sell order
#         elif signal == -1:
#             if available_base_amount > 0.00001:
#                 self.divide_quote = 0
#                 CA.log('Sell ' + base)
#                 CA.sell(exchange, pair, available_base_amount, CA.OrderType.MARKET)
#         return
# ' metadata={'source': 'Aroon-en.py'}

# %%
text_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, 
    chunk_size=2000, 
    chunk_overlap=500,
    length_function=len,
    add_start_index=True
)
text_chunks = text_splitter.split_documents(documents)

# %%
# View the chunks that has the source of 'RSI-en.py'
rsi_chunks = [chunk for chunk in text_chunks if chunk.metadata['source'] == 'RSI-en.py']
for chunk in rsi_chunks:
    print(chunk.metadata)
# Out:
# {'source': 'RSI-en.py', 'start_index': 0}
# {'source': 'RSI-en.py', 'start_index': 1302}
# {'source': 'RSI-en.py', 'start_index': 2626}
# {'source': 'RSI-en.py', 'start_index': 4201}

# %%
vectorstore = Chroma.from_documents(documents=text_chunks, embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()

# %%
system_prompt = (
    """
    You are a coding assistant with expertise in Crypto Arsenal's documentation.Here is a set of Crypto Arsenal's documentation retrieved to answer the question: \n -------- \n {context} \n -------- \n Ensure any code you provide can be executed with all the required imports and variables defined. If you do not know the answer or require further clarification, just say that you do not know.
    """
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response_1 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_1["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code snippet provided from Crypto Arsenal's documentation. Here's a modified version of the code snippet:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_lower_band = 30
#         self.rsi_upper_band = 70
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         if len(close_price_history) < self.long_period + 1:
#             return []
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         signal = 0
#
#         if curr_rsi_short < self.rsi_lower_band:
#             signal = 1  # Buy signal
#         elif curr_rsi_short > self.rsi_upper_band:
#             signal = -1  # Sell signal
#
#         if signal == 1:
#             CA.log('Buy Bitcoin')
#             return [
#                 {
#                     'exchange': exchange,
#                     'amount': 1,  # You can adjust the amount based on your strategy
#                     'price': -1,
#                     'type': 'MARKET',
#                     'pair': pair,
#                     'margin': True,
#                 }
#             ]
#         elif signal == -1:
#             CA.log('Sell Bitcoin')
#             return [
#                 {
#                     'exchange': exchange,
#                     'amount': -1,  # You can adjust the amount based on your strategy
#                     'price': -1,
#                     'type': 'MARKET',
#                     'pair': pair,
#                     'margin': True,
#                 }
#             ]
# ```
#
# In this modified code snippet, the strategy checks the RSI of Bitcoin and buys if the RSI drops below 30 and sells if it goes above 70. You can further customize the strategy parameters and actions based on your specific requirements and risk management rules.

# %%
for document in response_1["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_2 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_2["answer"])
# Out:
# To create a strategy where you buy Bitcoin if its RSI drops below 30 and sell if it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy based on your requirements:
#
# ```python
# import numpy as np
# import talib
#
# class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.short_period = 14  # RSI short period
#         self.long_period = 28  # RSI long period
#         self.rsi_lower_band = 30  # RSI lower band for buying
#         self.rsi_upper_band = 70  # RSI upper band for selling
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#
#         # Calculate RSI
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         # Current RSI values
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         # Buy if RSI drops below 30
#         if curr_rsi_short < self.rsi_lower_band and curr_rsi_long < self.rsi_lower_band:
#             CA.log('Buy Bitcoin - RSI below 30')
#             # Place buy order here
#
#         # Sell if RSI goes above 70
#         if curr_rsi_short > self.rsi_upper_band and curr_rsi_long > self.rsi_upper_band:
#             CA.log('Sell Bitcoin - RSI above 70')
#             # Place sell order here
# ```
#
# In this modified code:
# - The strategy calculates the RSI for short and long periods based on the close price history.
# - If the current RSI values for both short and long periods drop below 30, it logs a message to buy Bitcoin.
# - If the current RSI values for both short and long periods go above 70, it logs a message to sell Bitcoin.
#
# You can integrate this strategy into your trading platform, ensuring you have the necessary functions for placing buy and sell orders.

# %%
for document in response_2["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_3 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_3["answer"])
# Out:
# To create a strategy where you buy Bitcoin if its RSI drops below 30 and sell if it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here is a simplified version of the strategy based on the requirements:
#
# ```python
# import talib
# import numpy as np
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_lower_band = 30
#         self.rsi_upper_band = 70
#         self.divide_quote = 0
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(close_price_history, self.short_period)
#         rsi_long = talib.RSI(close_price_history, self.long_period)
#
#         if len(close_price_history) < self.long_period + 1:
#             return []
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         signal = 0
#
#         if curr_rsi_short < self.rsi_lower_band:
#             signal = 1  # Buy signal
#         elif curr_rsi_short > self.rsi_upper_band:
#             signal = -1  # Sell signal
#
#         return signal
#
# # Example usage
# strategy = RsiStrategy()
#
# # Assuming close_price_history is the historical close prices of Bitcoin
# close_price_history = np.random.rand(100)  # Random data for demonstration
#
# signal = strategy.trade(close_price_history)
# if signal == 1:
#     print("Buy Bitcoin")
# elif signal == -1:
#     print("Sell Bitcoin")
# ```
#
# In this code snippet:
# - The `RsiStrategy` class defines the strategy parameters and the `trade` method to determine the trading signal based on RSI values.
# - The strategy checks if the current RSI value is below 30 to generate a buy signal and above 70 to generate a sell signal.
# - You can integrate this strategy into your trading system by providing the historical close price data of Bitcoin to the `trade` method and executing the corresponding actions based on the generated signal.
#
# Please make sure to integrate this code snippet into your existing trading system and adapt it to your specific requirements and environment.

# %%
for document in response_3["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %% [markdown]
# ### Temperature = 0

# %%
# Reseting Chroma vectorstore collection
vectorstore.reset_collection()

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0)

# %%
folder_path = "strategy-template"

documents = []
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        loader = PythonLoader(file_path)
        loaded_docs = loader.load()
        # Add source metadata to each document
        for doc in loaded_docs:
            doc.metadata["source"] = filename
        documents.extend(loaded_docs)

# %%
print(documents[0])
# Out:
# page_content='class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.subscribed_books = {}
#         self.period = 45 * 60
#         self.options = {}
#
#         self.divide_quote = 0
#         self.proportion = 0.2
#         self.aroon_period = 14
#
#     def on_order_state_change(self,  order):
#         pass
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#         high_price_history = [candle['high'] for candle in candles[exchange][pair]]
#         low_price_history = [candle['low'] for candle in candles[exchange][pair]]
#         open_price_history = [candle['open'] for candle in candles[exchange][pair]]
#
#         # convert to chronological order for talib
#         close_price_history.reverse()
#         high_price_history.reverse()
#         low_price_history.reverse()
#         open_price_history.reverse()
#
#         # convert to np.array
#         close_price_history = np.array(close_price_history)
#         high_price_history = np.array(high_price_history)
#         low_price_history = np.array(low_price_history)
#         open_price_history = np.array(open_price_history)
#
#         close_price = close_price_history[-1]
#         high_price = high_price_history[-1]
#
#         # get available balance
#         base_balance = CA.get_balance(exchange, base)
#         quote_balance = CA.get_balance(exchange, quote)
#         available_base_amount = base_balance.available
#         available_quote_amount = quote_balance.available
#
#         if self.divide_quote == 0:
#             self.divide_quote = np.round(available_quote_amount* self.proportion, 5)
#
#         aroondown, aroonup = talib.AROON(high_price_history, low_price_history, timeperiod=self.aroon_period)
#         aroon_down = aroondown[-1]
#         aroon_up = aroonup[-1]
#
#         signal = 0
#         # Aroon-Up above 50 and Aroon-Up larger than Aroon-Down mean the market is bullish
#         if aroon_up > 50 and aroon_up > aroon_down:
#             signal = 1
#
#         # Aroon-Down above 50 and Aroon-Dwon larger than Aroon-Up mean the market is bearish
#         elif aroon_down > 50 and aroon_down > aroon_up:
#             signal = -1
#
#         # place buy order
#         if signal == 1:
#             amount = self.divide_quote/high_price
#             if available_quote_amount >= amount * close_price:
#                 CA.log('Buy ' + base)
#                 CA.buy(exchange, pair, amount, CA.OrderType.MARKET)
#
#         # place sell order
#         elif signal == -1:
#             if available_base_amount > 0.00001:
#                 self.divide_quote = 0
#                 CA.log('Sell ' + base)
#                 CA.sell(exchange, pair, available_base_amount, CA.OrderType.MARKET)
#         return
# ' metadata={'source': 'Aroon-en.py'}

# %%
text_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, 
    chunk_size=2000, 
    chunk_overlap=500,
    length_function=len,
    add_start_index=True
)
text_chunks = text_splitter.split_documents(documents)

# %%
# View the chunks that has the source of 'RSI-en.py'
rsi_chunks = [chunk for chunk in text_chunks if chunk.metadata['source'] == 'RSI-en.py']
for chunk in rsi_chunks:
    print(chunk.metadata)
# Out:
# {'source': 'RSI-en.py', 'start_index': 0}
# {'source': 'RSI-en.py', 'start_index': 1302}
# {'source': 'RSI-en.py', 'start_index': 2626}
# {'source': 'RSI-en.py', 'start_index': 4201}

# %%
vectorstore = Chroma.from_documents(documents=text_chunks, embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()

# %%
system_prompt = (
    """
    You are a coding assistant with expertise in Crypto Arsenal's documentation.Here is a set of Crypto Arsenal's documentation retrieved to answer the question: \n -------- \n {context} \n -------- \n Ensure any code you provide can be executed with all the required imports and variables defined. If you do not know the answer or require further clarification, just say that you do not know.
    """
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response_1 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_1["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy implementation:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_upper_band = 70
#         self.rsi_lower_band = 30
#         self.is_long = False
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if curr_rsi_short < self.rsi_lower_band and not self.is_long:
#             self.is_long = True
#             return "Buy Bitcoin"
#
#         if curr_rsi_short > self.rsi_upper_band and self.is_long:
#             self.is_long = False
#             return "Sell Bitcoin"
#
#         return "Hold Bitcoin"
#
# # Example usage
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# rsi_strategy = RsiStrategy()
# for i in range(len(close_prices)):
#     action = rsi_strategy.trade(close_prices[:i+1])
#     print(f"Day {i+1}: {action}")
# ```
#
# In this code snippet:
# - The `RsiStrategy` class defines the strategy based on RSI values.
# - The `trade` method checks the RSI values and determines whether to buy, sell, or hold Bitcoin.
# - The strategy buys Bitcoin when the RSI drops below 30 and sells when it goes above 70.
# - The example usage demonstrates how the strategy can be applied to a list of historical close prices.
#
# You can integrate this strategy into your trading platform by adapting it to your specific environment and data feed.

# %%
for document in response_1["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_2 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_2["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy implementation:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_lower_band = 30
#         self.rsi_upper_band = 70
#         self.is_long = False
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if curr_rsi_short < self.rsi_lower_band and not self.is_long:
#             # Buy Bitcoin
#             self.is_long = True
#             return "Buy Bitcoin"
#
#         elif curr_rsi_short > self.rsi_upper_band and self.is_long:
#             # Sell Bitcoin
#             self.is_long = False
#             return "Sell Bitcoin"
#
#         return "Hold"
#
# # Example usage
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# rsi_strategy = RsiStrategy()
# for i in range(len(close_prices)):
#     action = rsi_strategy.trade(close_prices[:i+1])
#     print(f"Day {i+1}: {action}")
# ```
#
# In this code snippet:
# - The `RsiStrategy` class defines the strategy with RSI parameters and a boolean flag `is_long` to track the position.
# - The `trade` method calculates RSI values and determines whether to buy, sell, or hold based on the RSI conditions.
# - The example usage demonstrates how the strategy can be applied to a list of closing prices.
#
# You can integrate this strategy into your trading platform by incorporating it into the existing trading logic or framework.

# %%
for document in response_2["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_3 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_3["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy implementation:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_upper_band = 70
#         self.rsi_lower_band = 30
#         self.is_long = False
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if curr_rsi_short < self.rsi_lower_band and not self.is_long:
#             self.is_long = True
#             return "Buy Bitcoin"
#         elif curr_rsi_short > self.rsi_upper_band and self.is_long:
#             self.is_long = False
#             return "Sell Bitcoin"
#         else:
#             return "Hold Bitcoin"
#
# # Example usage
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# rsi_strategy = RsiStrategy()
# for i in range(len(close_prices)):
#     action = rsi_strategy.trade(close_prices[:i+1])
#     print(f"Day {i+1}: {action}")
# ```
#
# In this code snippet:
# - The `RsiStrategy` class defines the strategy based on RSI values.
# - The `trade` method calculates RSI values and determines whether to buy, sell, or hold Bitcoin based on the RSI conditions.
# - The example usage demonstrates how the strategy can be applied to a sequence of closing prices.
#
# You can integrate this strategy into your trading platform by adapting it to your specific environment and requirements.

# %%
for document in response_3["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %% [markdown]
# ## Model Seed

# %% [markdown]
# ### Seed = 100

# %%
# Reseting Chroma vectorstore collection
vectorstore.reset_collection()

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0, seed=100)

# %%
folder_path = "strategy-template"

documents = []
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        loader = PythonLoader(file_path)
        loaded_docs = loader.load()
        # Add source metadata to each document
        for doc in loaded_docs:
            doc.metadata["source"] = filename
        documents.extend(loaded_docs)

# %%
print(documents[0])
# Out:
# page_content='class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.subscribed_books = {}
#         self.period = 45 * 60
#         self.options = {}
#
#         self.divide_quote = 0
#         self.proportion = 0.2
#         self.aroon_period = 14
#
#     def on_order_state_change(self,  order):
#         pass
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#         high_price_history = [candle['high'] for candle in candles[exchange][pair]]
#         low_price_history = [candle['low'] for candle in candles[exchange][pair]]
#         open_price_history = [candle['open'] for candle in candles[exchange][pair]]
#
#         # convert to chronological order for talib
#         close_price_history.reverse()
#         high_price_history.reverse()
#         low_price_history.reverse()
#         open_price_history.reverse()
#
#         # convert to np.array
#         close_price_history = np.array(close_price_history)
#         high_price_history = np.array(high_price_history)
#         low_price_history = np.array(low_price_history)
#         open_price_history = np.array(open_price_history)
#
#         close_price = close_price_history[-1]
#         high_price = high_price_history[-1]
#
#         # get available balance
#         base_balance = CA.get_balance(exchange, base)
#         quote_balance = CA.get_balance(exchange, quote)
#         available_base_amount = base_balance.available
#         available_quote_amount = quote_balance.available
#
#         if self.divide_quote == 0:
#             self.divide_quote = np.round(available_quote_amount* self.proportion, 5)
#
#         aroondown, aroonup = talib.AROON(high_price_history, low_price_history, timeperiod=self.aroon_period)
#         aroon_down = aroondown[-1]
#         aroon_up = aroonup[-1]
#
#         signal = 0
#         # Aroon-Up above 50 and Aroon-Up larger than Aroon-Down mean the market is bullish
#         if aroon_up > 50 and aroon_up > aroon_down:
#             signal = 1
#
#         # Aroon-Down above 50 and Aroon-Dwon larger than Aroon-Up mean the market is bearish
#         elif aroon_down > 50 and aroon_down > aroon_up:
#             signal = -1
#
#         # place buy order
#         if signal == 1:
#             amount = self.divide_quote/high_price
#             if available_quote_amount >= amount * close_price:
#                 CA.log('Buy ' + base)
#                 CA.buy(exchange, pair, amount, CA.OrderType.MARKET)
#
#         # place sell order
#         elif signal == -1:
#             if available_base_amount > 0.00001:
#                 self.divide_quote = 0
#                 CA.log('Sell ' + base)
#                 CA.sell(exchange, pair, available_base_amount, CA.OrderType.MARKET)
#         return
# ' metadata={'source': 'Aroon-en.py'}

# %%
text_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, 
    chunk_size=2000, 
    chunk_overlap=500,
    length_function=len,
    add_start_index=True
)
text_chunks = text_splitter.split_documents(documents)

# %%
# View the chunks that has the source of 'RSI-en.py'
rsi_chunks = [chunk for chunk in text_chunks if chunk.metadata['source'] == 'RSI-en.py']
for chunk in rsi_chunks:
    print(chunk.metadata)
# Out:
# {'source': 'RSI-en.py', 'start_index': 0}
# {'source': 'RSI-en.py', 'start_index': 1302}
# {'source': 'RSI-en.py', 'start_index': 2626}
# {'source': 'RSI-en.py', 'start_index': 4201}

# %%
vectorstore = Chroma.from_documents(documents=text_chunks, embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()

# %%
system_prompt = (
    """
    You are a coding assistant with expertise in Crypto Arsenal's documentation.Here is a set of Crypto Arsenal's documentation retrieved to answer the question: \n -------- \n {context} \n -------- \n Ensure any code you provide can be executed with all the required imports and variables defined. If you do not know the answer or require further clarification, just say that you do not know.
    """
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response_1 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_1["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy implementation:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_upper_band = 70
#         self.rsi_lower_band = 30
#         self.is_long = False
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if curr_rsi_short < self.rsi_lower_band and not self.is_long:
#             self.is_long = True
#             return "Buy Bitcoin"
#         elif curr_rsi_short > self.rsi_upper_band and self.is_long:
#             self.is_long = False
#             return "Sell Bitcoin"
#         else:
#             return "Hold"
#
# # Example usage
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# rsi_strategy = RsiStrategy()
# for i in range(len(close_prices)):
#     action = rsi_strategy.trade(close_prices[:i+1])
#     print(f"Day {i+1}: {action}")
# ```
#
# In this code snippet:
# - The `RsiStrategy` class defines the RSI strategy with parameters for RSI periods and upper/lower bands.
# - The `trade` method calculates RSI values and determines whether to buy, sell, or hold based on the RSI conditions.
# - The example usage demonstrates how you can apply the strategy to a list of historical close prices.
#
# You can integrate this strategy into your trading platform by adapting it to interact with your exchange API and account balances.

# %%
for document in response_1["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_2 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_2["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy implementation:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_upper_band = 70
#         self.rsi_lower_band = 30
#         self.divide_quote = 0
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(close_price_history, self.short_period)
#         rsi_long = talib.RSI(close_price_history, self.long_period)
#
#         if len(close_price_history) < self.long_period + 1:
#             return []
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         prev_rsi_short = rsi_short[-2]
#         prev_rsi_long = rsi_long[-2]
#
#         signal = 0
#
#         if curr_rsi_short < self.rsi_lower_band and prev_rsi_short > prev_rsi_long:
#             signal = 1  # Buy signal
#         elif curr_rsi_short > self.rsi_upper_band and prev_rsi_short < prev_rsi_long:
#             signal = -1  # Sell signal
#
#         return signal
#
# # Example usage
# strategy = RsiStrategy()
#
# # Simulated close price history data
# close_prices = np.random.random(100) * 100
#
# # Simulated trading loop
# for i in range(len(close_prices)):
#     signal = strategy.trade(close_prices[:i+1])
#     if signal == 1:
#         print("Buy Bitcoin at price:", close_prices[i])
#     elif signal == -1:
#         print("Sell Bitcoin at price:", close_prices[i])
# ```
#
# In this code snippet:
# - The `RsiStrategy` class defines the strategy parameters and logic for buying when RSI drops below 30 and selling when RSI goes above 70.
# - The `trade` method calculates the RSI values, compares them with the defined bands, and generates buy or sell signals.
# - The example usage demonstrates how you can use the strategy within a trading loop with simulated close price history data.
#
# You can integrate this strategy into your trading platform by adapting it to interact with your exchange API and account balances.

# %%
for document in response_2["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_3 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_3["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy implementation:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_upper_band = 70
#         self.rsi_lower_band = 30
#         self.divide_quote = 0
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(close_price_history, self.short_period)
#         rsi_long = talib.RSI(close_price_history, self.long_period)
#
#         if len(close_price_history) < self.long_period + 1:
#             return []
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if curr_rsi_short < self.rsi_lower_band:
#             # Buy Bitcoin
#             return "Buy"
#
#         if curr_rsi_short > self.rsi_upper_band:
#             # Sell Bitcoin
#             return "Sell"
#
#         return "Hold"
#
# # Example usage
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# rsi_strategy = RsiStrategy()
# trade_signal = rsi_strategy.trade(np.array(close_prices))
#
# print(trade_signal)
# ```
#
# In this code snippet:
# - The `RsiStrategy` class defines the strategy parameters and the `trade` method to determine the trading signals based on RSI values.
# - The strategy checks if the current RSI value is below 30 to trigger a buy signal and above 70 to trigger a sell signal.
# - You can adjust the `close_prices` list with historical Bitcoin prices to test the strategy.
#
# Please ensure you have the necessary libraries imported and the required data available to run this code successfully. Let me know if you need further assistance or modifications.

# %%
for document in response_3["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %% [markdown]
# ### Seed = 999

# %%
# Reseting Chroma vectorstore collection
vectorstore.reset_collection()

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0, seed=999)

# %%
folder_path = "strategy-template"

documents = []
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        loader = PythonLoader(file_path)
        loaded_docs = loader.load()
        # Add source metadata to each document
        for doc in loaded_docs:
            doc.metadata["source"] = filename
        documents.extend(loaded_docs)

# %%
print(documents[0])
# Out:
# page_content='class Strategy(StrategyBase):
#     def __init__(self):
#         # strategy property
#         self.subscribed_books = {}
#         self.period = 45 * 60
#         self.options = {}
#
#         self.divide_quote = 0
#         self.proportion = 0.2
#         self.aroon_period = 14
#
#     def on_order_state_change(self,  order):
#         pass
#
#     def trade(self, candles):
#         exchange, pair, base, quote = CA.get_exchange_pair()
#
#         close_price_history = [candle['close'] for candle in candles[exchange][pair]]
#         high_price_history = [candle['high'] for candle in candles[exchange][pair]]
#         low_price_history = [candle['low'] for candle in candles[exchange][pair]]
#         open_price_history = [candle['open'] for candle in candles[exchange][pair]]
#
#         # convert to chronological order for talib
#         close_price_history.reverse()
#         high_price_history.reverse()
#         low_price_history.reverse()
#         open_price_history.reverse()
#
#         # convert to np.array
#         close_price_history = np.array(close_price_history)
#         high_price_history = np.array(high_price_history)
#         low_price_history = np.array(low_price_history)
#         open_price_history = np.array(open_price_history)
#
#         close_price = close_price_history[-1]
#         high_price = high_price_history[-1]
#
#         # get available balance
#         base_balance = CA.get_balance(exchange, base)
#         quote_balance = CA.get_balance(exchange, quote)
#         available_base_amount = base_balance.available
#         available_quote_amount = quote_balance.available
#
#         if self.divide_quote == 0:
#             self.divide_quote = np.round(available_quote_amount* self.proportion, 5)
#
#         aroondown, aroonup = talib.AROON(high_price_history, low_price_history, timeperiod=self.aroon_period)
#         aroon_down = aroondown[-1]
#         aroon_up = aroonup[-1]
#
#         signal = 0
#         # Aroon-Up above 50 and Aroon-Up larger than Aroon-Down mean the market is bullish
#         if aroon_up > 50 and aroon_up > aroon_down:
#             signal = 1
#
#         # Aroon-Down above 50 and Aroon-Dwon larger than Aroon-Up mean the market is bearish
#         elif aroon_down > 50 and aroon_down > aroon_up:
#             signal = -1
#
#         # place buy order
#         if signal == 1:
#             amount = self.divide_quote/high_price
#             if available_quote_amount >= amount * close_price:
#                 CA.log('Buy ' + base)
#                 CA.buy(exchange, pair, amount, CA.OrderType.MARKET)
#
#         # place sell order
#         elif signal == -1:
#             if available_base_amount > 0.00001:
#                 self.divide_quote = 0
#                 CA.log('Sell ' + base)
#                 CA.sell(exchange, pair, available_base_amount, CA.OrderType.MARKET)
#         return
# ' metadata={'source': 'Aroon-en.py'}

# %%
text_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, 
    chunk_size=2000, 
    chunk_overlap=500,
    length_function=len,
    add_start_index=True
)
text_chunks = text_splitter.split_documents(documents)

# %%
# View the chunks that has the source of 'RSI-en.py'
rsi_chunks = [chunk for chunk in text_chunks if chunk.metadata['source'] == 'RSI-en.py']
for chunk in rsi_chunks:
    print(chunk.metadata)
# Out:
# {'source': 'RSI-en.py', 'start_index': 0}
# {'source': 'RSI-en.py', 'start_index': 1302}
# {'source': 'RSI-en.py', 'start_index': 2626}
# {'source': 'RSI-en.py', 'start_index': 4201}

# %%
vectorstore = Chroma.from_documents(documents=text_chunks, embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()

# %%
system_prompt = (
    """
    You are a coding assistant with expertise in Crypto Arsenal's documentation.Here is a set of Crypto Arsenal's documentation retrieved to answer the question: \n -------- \n {context} \n -------- \n Ensure any code you provide can be executed with all the required imports and variables defined. If you do not know the answer or require further clarification, just say that you do not know.
    """
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response_1 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_1["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy based on the requirements:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14  # RSI short period
#         self.long_period = 28  # RSI long period
#         self.rsi_lower_band = 30  # RSI lower band for buying
#         self.rsi_upper_band = 70  # RSI upper band for selling
#         self.is_long = False  # Flag to track if in a long position
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         if len(close_price_history) < self.long_period + 1:
#             return []
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if not self.is_long and curr_rsi_short < self.rsi_lower_band and curr_rsi_long < self.rsi_lower_band:
#             # Buy Bitcoin
#             self.is_long = True
#             return "Buy Bitcoin"
#
#         elif self.is_long and (curr_rsi_short > self.rsi_upper_band or curr_rsi_long > self.rsi_upper_band):
#             # Sell Bitcoin
#             self.is_long = False
#             return "Sell Bitcoin"
#
#         return "Hold"
#
# # Example usage
# strategy = RsiStrategy()
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# for i in range(5, len(close_prices)):
#     action = strategy.trade(close_prices[:i])
#     print(f"At price {close_prices[i]}, Action: {action}")
# ```
#
# In this code:
# - The `RsiStrategy` class defines the strategy parameters and logic.
# - The `trade` method calculates the RSI values, checks the conditions for buying and selling based on RSI thresholds, and returns the corresponding action.
# - The example usage demonstrates how you can use the strategy with a list of close prices.
#
# You can integrate this strategy into your trading platform by adapting it to interact with your exchange API and account balances.

# %%
for document in response_1["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_2 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_2["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy implementation:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_upper_band = 70
#         self.rsi_lower_band = 30
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if curr_rsi_short < self.rsi_lower_band:
#             # Buy Bitcoin
#             return "Buy"
#         elif curr_rsi_short > self.rsi_upper_band:
#             # Sell Bitcoin
#             return "Sell"
#         else:
#             return "Hold"
#
# # Example usage
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# rsi_strategy = RsiStrategy()
# trade_signal = rsi_strategy.trade(close_prices)
# print(trade_signal)
# ```
#
# In this code snippet:
# - The `RsiStrategy` class is created to define the RSI strategy parameters and trading logic.
# - The `trade` method calculates the RSI values based on the provided `close_price_history` and generates trade signals accordingly.
# - If the current RSI drops below 30, it returns "Buy" as a trade signal.
# - If the current RSI goes above 70, it returns "Sell" as a trade signal.
# - Otherwise, it returns "Hold" indicating no action is needed.
#
# You can adjust the `close_prices` list with actual historical Bitcoin prices to test the strategy. This code provides a basic framework for implementing an RSI-based trading strategy.

# %%
for document in response_2["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045

# %%
response_3 = rag_chain.invoke({"input": "I want to create a strategy where I buy Bitcoin if its RSI drops below 30 and sell if it goes above 70."})
print(response_3["answer"])
# Out:
# To create a strategy where you buy Bitcoin when its Relative Strength Index (RSI) drops below 30 and sell when it goes above 70, you can modify the existing code provided from Crypto Arsenal's documentation. Here's a simplified version of the strategy based on the requirements:
#
# ```python
# import numpy as np
# import talib
#
# class RsiStrategy:
#     def __init__(self):
#         self.short_period = 14
#         self.long_period = 28
#         self.rsi_lower_band = 30
#         self.rsi_upper_band = 70
#
#     def trade(self, close_price_history):
#         rsi_short = talib.RSI(np.array(close_price_history), self.short_period)
#         rsi_long = talib.RSI(np.array(close_price_history), self.long_period)
#
#         curr_rsi_short = rsi_short[-1]
#         curr_rsi_long = rsi_long[-1]
#
#         if curr_rsi_short < self.rsi_lower_band:
#             # Buy Bitcoin
#             return "Buy"
#         elif curr_rsi_short > self.rsi_upper_band:
#             # Sell Bitcoin
#             return "Sell"
#         else:
#             return "Hold"
#
# # Example usage
# close_prices = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190]
# rsi_strategy = RsiStrategy()
# trade_signal = rsi_strategy.trade(close_prices)
# print(trade_signal)
# ```
#
# In this code snippet:
# - The `RsiStrategy` class is created to define the RSI strategy parameters and trading logic.
# - The `trade` method calculates the RSI values based on the provided `close_price_history` and generates trade signals accordingly.
# - If the current RSI drops below 30, the strategy suggests buying Bitcoin. If the RSI goes above 70, it suggests selling Bitcoin. Otherwise, it holds the position.
# - You can test this strategy by providing a list of historical closing prices for Bitcoin and checking the trade signal generated by the strategy.
#
# Please ensure you have the necessary libraries imported and the required variables defined before running this code. Let me know if you need further assistance or modifications.

# %%
for document in response_3["context"]:
    print(f"Source: {document.metadata['source']}, Start_index: {document.metadata['start_index']}")
    #print(document.page_content)
    #print('#############################################################')
# Out:
# Source: RSI-en.py, Start_index: 2626
# Source: RSI-en.py, Start_index: 1302
# Source: RSI-en.py, Start_index: 0
# Source: Bollinger_Bands-en.py, Start_index: 2045
