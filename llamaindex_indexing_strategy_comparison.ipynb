# %% [markdown]
# # LlamaIndex Indexing Strategy Comparison
# Comparing RAG response between different LlamaIndex Strategies:
# - VectorStore Index
# - Summary Index
# - Tree Index
# - Keyword Table Index
# - Property Graph Index
#
# Comparison is tested on two types of datasets:
# 1) Essay - with queries closer to QnA tasks
# 2) Code - for code generation task
#
# Indices used are set to default versions, and LLM model used is `gpt-3.5-turbo-0125` with `temperature=0`

# %%
# Using llama-index-core (0.10.68)
# %pip install --user -qU llama-index-llms-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow-intel (c:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (c:\Users\User\anaconda3\Lib\site-packages)

# %%
import os
import getpass

os.environ['OPENAI_API_KEY'] = getpass.getpass()

# %%
# get API key and create embeddings
from llama_index.embeddings.openai import OpenAIEmbedding

embed_model = OpenAIEmbedding(model="text-embedding-3-large")

embeddings = embed_model.get_text_embedding(
    "Open AI new Embeddings models is great."
)

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings

embed_model = OpenAIEmbedding(embed_batch_size=10)
Settings.embed_model = embed_model
Settings.llm = OpenAI(temperature=0, model="gpt-3.5-turbo-0125")

# %% [markdown]
# # Essay Dataset
# Using the Paul Graham Essay Dataset from LlamaIndex
#
# https://llamahub.ai/l/llama_datasets/Paul%20Graham%20Essay?from=llama_datasets

# %%
from llama_index.core.llama_dataset import download_llama_dataset

# download and install dependencies
essay_dataset, essay_documents = download_llama_dataset(
    "PaulGrahamEssayDataset", "./paul_graham"
)

# %%
essay_dataset.to_pandas()[:5]
# Out:
#                                                query  \
# 0  In the essay, the author mentions his early ex...
# 1  The author switched his major from philosophy ...
# 2  In the essay, the author discusses his initial...
# 3  The author mentions his shift of interest towa...
# 4  In the essay, the author mentions his interest...
#
#                                   reference_contexts  \
# 0  [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 1  [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 2  [I couldn't have put this into words when I wa...
# 3  [I couldn't have put this into words when I wa...
# 4  [So I looked around to see what I could salvag...
#
#                                     reference_answer reference_answer_by  \
# 0  The first computer the author used for program...          ai (gpt-4)
# 1  The two specific influences that led the autho...          ai (gpt-4)
# 2  The two main influences that initially drew th...          ai (gpt-4)
# 3  The author shifted his interest towards Lisp a...          ai (gpt-4)
# 4  The author in the essay is Paul Graham, who wa...          ai (gpt-4)
#
#      query_by
# 0  ai (gpt-4)
# 1  ai (gpt-4)
# 2  ai (gpt-4)
# 3  ai (gpt-4)
# 4  ai (gpt-4)

# %%
essay_dataset = essay_dataset.to_pandas()

# %%
test_query = essay_dataset.loc[0, 'query']
print(f'Test query: \n{test_query}')
print()
test_answer = essay_dataset.loc[0, 'reference_answer']
print(f'Test answer: \n{test_answer}')
print()
test_reference = essay_dataset.loc[0, 'reference_contexts']
print(f'Test reference: \n{test_reference}')
# Out:
# Test query:
# In the essay, the author mentions his early experiences with programming. Describe the first computer he used for programming, the language he used, and the challenges he faced.
#
# Test answer:
# The first computer the author used for programming was the IBM 1401, which was used by his school district for data processing. He started using it in 9th grade, around the age of 13 or 14. The programming language he used was an early version of Fortran. The author faced several challenges while using this computer. The only form of input to programs was data stored on punched cards, and he didn't have any data stored on punched cards. The only other option was to do things that didn't rely on any input, like calculate approximations of pi, but he didn't know enough math to do anything interesting of that type. Therefore, he couldn't figure out what to do with it and in retrospect, he believes there's not much he could have done with it.
#
# Test reference:
# ['What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn\'t write essays. I wrote what beginning writers were supposed to write then, and probably still are: short stories. My stories were awful. They had hardly any plot, just characters with strong feelings, which I imagined made them deep.\n\nThe first programs I tried writing were on the IBM 1401 that our school district used for what was then called "data processing." This was in 9th grade, so I was 13 or 14. The school district\'s 1401 happened to be in the basement of our junior high school, and my friend Rich Draves and I got permission to use it. It was like a mini Bond villain\'s lair down there, with all these alien-looking machines — CPU, disk drives, printer, card reader — sitting up on a raised floor under bright fluorescent lights.\n\nThe language we used was an early version of Fortran. You had to type programs on punch cards, then stack them in the card reader and press a button to load the program into memory and run it. The result would ordinarily be to print something on the spectacularly loud printer.\n\nI was puzzled by the 1401. I couldn\'t figure out what to do with it. And in retrospect there\'s not much I could have done with it. The only form of input to programs was data stored on punched cards, and I didn\'t have any data stored on punched cards. The only other option was to do things that didn\'t rely on any input, like calculate approximations of pi, but I didn\'t know enough math to do anything interesting of that type. So I\'m not surprised I can\'t remember any programs I wrote, because they can\'t have done much. My clearest memory is of the moment I learned it was possible for programs not to terminate, when one of mine didn\'t. On a machine without time-sharing, this was a social as well as a technical error, as the data center manager\'s expression made clear.\n\nWith microcomputers, everything changed. Now you could have a computer sitting right in front of you, on a desk, that could respond to your keystrokes as it was running instead of just churning through a stack of punch cards and then stopping. [1]\n\nThe first of my friends to get a microcomputer built it himself. It was sold as a kit by Heathkit. I remember vividly how impressed and envious I felt watching him sitting in front of it, typing programs right into the computer.\n\nComputers were expensive in those days and it took me years of nagging before I convinced my father to buy one, a TRS-80, in about 1980. The gold standard then was the Apple II, but a TRS-80 was good enough. This was when I really started programming. I wrote simple games, a program to predict how high my model rockets would fly, and a word processor that my father used to write at least one book. There was only room in memory for about 2 pages of text, so he\'d write 2 pages at a time and then print them out, but it was a lot better than a typewriter.\n\nThough I liked programming, I didn\'t plan to study it in college. In college I was going to study philosophy, which sounded much more powerful. It seemed, to my naive high school self, to be the study of the ultimate truths, compared to which the things studied in other fields would be mere domain knowledge. What I discovered when I got to college was that the other fields took up so much of the space of ideas that there wasn\'t much left for these supposed ultimate truths. All that seemed left for philosophy were edge cases that people in other fields felt could safely be ignored.\n\nI couldn\'t have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to switch to AI.\n\nAI was in the air in the mid 1980s, but there were two things especially that made me want to work on it: a novel by Heinlein called The Moon is a Harsh Mistress, which featured an intelligent computer called Mike, a ...

# %% [markdown]
# ## Vectorstore Index
# https://docs.llamaindex.ai/en/stable/module_guides/indexing/vector_store_guide/

# %%
from llama_index.core import VectorStoreIndex
vectorstore_index = VectorStoreIndex.from_documents(essay_documents)
vectorstore_query_engine = vectorstore_index.as_query_engine()

response = vectorstore_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# The author's first experience with programming was on an IBM 1401 in 9th grade. The computer was located in the basement of his junior high school. The language he used was an early version of Fortran. One of the challenges he faced was the limited input options for programs, as the only form of input was data stored on punched cards, which he did not have access to. This limitation led him to struggle with finding meaningful tasks to perform with the computer.

# %% [markdown]
# ## Summary Index
# https://docs.llamaindex.ai/en/stable/examples/index_structs/doc_summary/DocSummary/

# %%
from llama_index.core import DocumentSummaryIndex
document_summary_index = DocumentSummaryIndex.from_documents(essay_documents)
document_summary_query_engine = document_summary_index.as_query_engine()

response = document_summary_query_engine.query(
    test_query
)
# Out:
# current doc id: 8c929378-8da2-4a28-8369-dcea88d4018e

# %%
print(response)
# Out:
# The author's first experience with programming was on an IBM 1401 computer in 9th grade. The language used was an early version of Fortran. The challenges he faced included not being able to figure out what to do with the computer, the limited input options through punched cards, and the lack of stored data for input. This led to difficulties in creating meaningful programs due to the constraints of the system.

# %% [markdown]
# ## Tree Index
#
# https://docs.llamaindex.ai/en/stable/api_reference/indices/tree/#llama_index.core.indices.TreeIndex

# %%
from llama_index.core import TreeIndex
tree_index = TreeIndex.from_documents(essay_documents)
tree_index_query_engine = tree_index.as_query_engine()

response = tree_index_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# The author's first experience with programming was on an IBM 1401 computer in 9th grade. The language used was an early version of Fortran. The main challenge he faced was the limited input options as the only form of input was data stored on punched cards, which he did not have access to. This limitation made it difficult for him to create programs that could perform meaningful tasks.

# %% [markdown]
# ## Keyword Table Index
# https://docs.llamaindex.ai/en/stable/api_reference/indices/keyword/#llama_index.core.indices.KeywordTableIndex

# %%
from llama_index.core import KeywordTableIndex
keyword_table_index = KeywordTableIndex.from_documents(essay_documents)
keyword_table_index_query_engine = keyword_table_index.as_query_engine()

response = keyword_table_index_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# The author's first experience with programming was on an IBM 1401 computer in 9th grade. The language used was an early version of Fortran. The author faced challenges due to the limited input options, as the only form of input was data stored on punched cards, and the author did not have any data stored on punched cards. This limited the author's ability to create meaningful programs on the IBM 1401.

# %% [markdown]
# ## Property Graph Index
# https://docs.llamaindex.ai/en/stable/module_guides/indexing/lpg_index_guide/

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import PropertyGraphIndex
property_graph_index = PropertyGraphIndex.from_documents(essay_documents,)
property_graph_index_query_engine = property_graph_index.as_query_engine()

response = property_graph_index_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# The author mentions his early experiences with programming on the IBM 704 machine language. He used Lisp for programming, which was initially intended as a formal model of computation rather than a traditional programming language. The challenges he faced included the limitations of McCarthy's original Lisp interpreter, which lacked many features needed in a programming language. McCarthy had to test the interpreter by hand-simulating program executions due to the lack of powerful enough computers at the time.

# %% [markdown]
# # Code Dataset
#
# reference: https://code-rag-bench.github.io/
#
# RAG with canonical datastore
# - target repository
#
# RAG with open datastore
# - research paper suggest that retreiving from a larger datastore consist of documents from different sources could unlock effectiveness of code RAG.
#
# According to the paper, there are 4 types of code generation scenarios:
# 1. Basic Programming: interview-style problems, code completion
# 2. Open-domain: require beyond standard Python libraries (eg. `pandas`, web requests)
# 3. Repository-level: require editing files in context of an entire GitHub repository
# 4. Code-retrieval: code search/retrieval task to measure retrieval quality
#
# For simplicity, we will test on the first scenario (Basic Programming)

# %%
import pandas as pd

# Knowledge base comprising programming solutions for the HumanEval and MBPP datasets 
programming_solutions = pd.read_json("hf://datasets/code-rag-bench/programming-solutions/programming_solutions.json")

# %%
programming_solutions.head(5)
# Out:
#                      title                                               text  \
# 0       has_close_elements  from typing import List\n\n\ndef has_close_ele...
# 1    separate_paren_groups  from typing import List\n\n\ndef separate_pare...
# 2          truncate_number  \n\ndef truncate_number(number: float) -> floa...
# 3               below_zero  from typing import List\n\n\ndef below_zero(op...
# 4  mean_absolute_deviation  from typing import List\n\n\ndef mean_absolute...
#
#                                                 meta
# 0  {'task_name': 'humaneval', 'task_id': 'HumanEv...
# 1  {'task_name': 'humaneval', 'task_id': 'HumanEv...
# 2  {'task_name': 'humaneval', 'task_id': 'HumanEv...
# 3  {'task_name': 'humaneval', 'task_id': 'HumanEv...
# 4  {'task_name': 'humaneval', 'task_id': 'HumanEv...

# %%
from llama_index.core import Document

text_list = programming_solutions['text'].tolist()
code_documents = [Document(text=t) for t in text_list]
print(code_documents[0])
# Out:
# Doc ID: 55a5943a-9a2f-4216-9400-0d706307a457
# Text: from typing import List   def has_close_elements(numbers:
# List[float], threshold: float) -> bool:     """ Check if in given list
# of numbers, are any two numbers closer to each other than     given
# threshold.     >>> has_close_elements([1.0, 2.0, 3.0], 0.5)     False
# >>> has_close_elements([1.0, 2.8, 3.0, 4.0, 5.0, 2.0], 0.3)     True
# """...

# %%
print(len(code_documents))
# Out:
# 1128

# %%
import pandas as pd

humaneval_dataset = pd.read_json("hf://datasets/code-rag-bench/humaneval/humaneval.json", lines=True)

# %%
humaneval_dataset.head(5)
# Out:
#        task_id                                             prompt  \
# 0  HumanEval/0  from typing import List\n\n\ndef has_close_ele...
# 1  HumanEval/1  from typing import List\n\n\ndef separate_pare...
# 2  HumanEval/2  \n\ndef truncate_number(number: float) -> floa...
# 3  HumanEval/3  from typing import List\n\n\ndef below_zero(op...
# 4  HumanEval/4  from typing import List\n\n\ndef mean_absolute...
#
#                                   canonical_solution  \
# 0      for idx, elem in enumerate(numbers):\n    ...
# 1      result = []\n    current_string = []\n    ...
# 2                              return number % 1.0\n
# 3      balance = 0\n\n    for op in operations:\n...
# 4      mean = sum(numbers) / len(numbers)\n    re...
#
#                                                 test              entry_point  \
# 0  \n\nMETADATA = {\n    'author': 'jt',\n    'da...       has_close_elements
# 1  \n\nMETADATA = {\n    'author': 'jt',\n    'da...    separate_paren_groups
# 2  \n\nMETADATA = {\n    'author': 'jt',\n    'da...          truncate_number
# 3  \n\nMETADATA = {\n    'author': 'jt',\n    'da...               below_zero
# 4  \n\nMETADATA = {\n    'author': 'jt',\n    'da...  mean_absolute_deviation
#
#                                                 docs
# 0  [{'text': 'from typing import List
#
#
# def has_c...
# 1  [{'text': 'from typing import List
#
#
# def separ...
# 2  [{'text': '
#
# def truncate_number(number: float...
# 3  [{'text': 'from typing import List
#
#
# def below...
# 4  [{'text': 'from typing import List
#
#
# def mean_...

# %%
test_query = 'Please complete the following function:\n\n' + humaneval_dataset.loc[0, 'prompt']
print(f'Test query: \n{test_query}')
print()
test_answer = humaneval_dataset.loc[0, 'canonical_solution']
print(f'Test answer: \n{test_answer}')
print()
test_reference = humaneval_dataset.loc[0, 'docs'][0]['text']
print(f'Test reference: \n{test_reference}')
# Out:
# Test query:
# Please complete the following function:
#
# from typing import List
#
#
# def has_close_elements(numbers: List[float], threshold: float) -> bool:
#     """ Check if in given list of numbers, are any two numbers closer to each other than
#     given threshold.
#     >>> has_close_elements([1.0, 2.0, 3.0], 0.5)
#     False
#     >>> has_close_elements([1.0, 2.8, 3.0, 4.0, 5.0, 2.0], 0.3)
#     True
#     """
#
#
# Test answer:
#     for idx, elem in enumerate(numbers):
#         for idx2, elem2 in enumerate(numbers):
#             if idx != idx2:
#                 distance = abs(elem - elem2)
#                 if distance < threshold:
#                     return True
#
#     return False
#
#
# Test reference:
# from typing import List
#
#
# def has_close_elements(numbers: List[float], threshold: float) -> bool:
#     """ Check if in given list of numbers, are any two numbers closer to each other than
#     given threshold.
#     >>> has_close_elements([1.0, 2.0, 3.0], 0.5)
#     False
#     >>> has_close_elements([1.0, 2.8, 3.0, 4.0, 5.0, 2.0], 0.3)
#     True
#     """
#
#     for idx, elem in enumerate(numbers):
#         for idx2, elem2 in enumerate(numbers):
#             if idx != idx2:
#                 distance = abs(elem - elem2)
#                 if distance < threshold:
#                     return True
#
#     return False

# %% [markdown]
# ## Vectorstore Index

# %%
from llama_index.core import VectorStoreIndex
vectorstore_index = VectorStoreIndex.from_documents(code_documents)
vectorstore_query_engine = vectorstore_index.as_query_engine()

response = vectorstore_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# def has_close_elements(numbers: List[float], threshold: float) -> bool:
#     for idx, elem in enumerate(numbers):
#         for idx2, elem2 in enumerate(numbers):
#             if idx != idx2:
#                 distance = abs(elem - elem2)
#                 if distance < threshold:
#                     return True
#     return False

# %% [markdown]
# ## Summary Index

# %%
from llama_index.core import DocumentSummaryIndex
document_summary_index = DocumentSummaryIndex.from_documents(code_documents)
document_summary_query_engine = document_summary_index.as_query_engine()

response = document_summary_query_engine.query(
    test_query
)
# Out:
# current doc id: 55a5943a-9a2f-4216-9400-0d706307a457
# current doc id: 130aaed6-3876-4b81-82ed-98fff99cbf00
# current doc id: 1c629d98-29ec-4e18-9fa2-49411be94f75
# current doc id: 6bc5d325-4610-459b-a86d-c1c8da9ede6c
# current doc id: b148e93f-1d21-44b9-af5a-7bcd2747132d
# current doc id: d542249c-42ab-4602-b289-a34773d3ee8b
# current doc id: 86721095-dce0-4908-8ce5-1b38db83b7a3
# current doc id: be51563a-c0a1-4968-bb3f-9d19a2f5a808
# current doc id: d93bc3ce-fae6-4534-92d6-367418ba4f75
# current doc id: 7ec85c01-d583-46ba-9c8a-250ef2acc895
# current doc id: 1fd320d2-ea54-4801-98df-222bd8f200f0
# current doc id: 6509b4da-1894-481e-9e8e-a4c5fc2468d2
# current doc id: e8de2602-15db-4a52-9aba-7502d95ba81c
# current doc id: 4eed625f-676e-443e-be53-0d720a1708b1
# current doc id: fa17512a-14eb-4a4c-a4cb-afa656d01b3f
# current doc id: 3e7b5fe5-757a-4f45-ac4e-c7c1b0bf8320
# current doc id: 435368e0-9149-4e39-9ce8-de0ed171ddf5
# current doc id: c7cb121b-2dcd-4c7d-9161-4265c38b0971
# current doc id: 08671989-5d70-444b-8459-d19e7d3c7e97
# current doc id: b63eb1fb-4524-4d9e-adb6-035340299125
# current doc id: 52c558fe-d533-4392-a8d7-b3c220bc757b
# current doc id: 8a899a7a-273f-451c-9690-1f78c9d3c8c3
# current doc id: ef2dcfbb-8e8e-4003-ab94-8ba1782a5f45
# current doc id: a17f8c98-c2a5-477d-8e57-43438ba4b44c
# current doc id: a0cb3b10-e392-41ee-b75b-a2092b0f1395
# current doc id: 7f325ba7-fcad-4932-8b35-fc5f6285ce73
# current doc id: 0cacf09a-bc66-4ff8-a52e-9846c2759d10
# current doc id: ec02d5b0-32ee-4dff-8d03-f0cbce3d08cb
# current doc id: 281c739b-036d-4bcf-ac60-05f165469f05
# current doc id: 25a7e10c-9135-4df3-8d32-427843423c2c
# current doc id: 35906abd-073e-4060-a3b7-265c93762bfd
# current doc id: 460ea52e-cdf1-4375-895b-d91e28841807
# current doc id: 9b85c37e-5092-48bb-a13d-1b259005dd63
# current doc id: f8195263-b483-4edb-ab50-fe37e9c9848b
# current doc id: f9e2c7f6-45c7-4e07-9328-898f5158b077
# current doc id: 1e6768bd-9eb3-443b-9d60-cc47fbb33548
# current doc id: 44c004a1-fab1-4aee-b160-28bd82787eb2
# current doc id: 307735ad-788d-432c-8f06-58e02590f5da
# current doc id: 35e9b151-6a05-4f0a-817e-1c606b882f8b
# current doc id: 984d1dca-d731-4207-846c-c5a4ae7f5909
# current doc id: 20e18534-15f7-4126-be23-b881a3eea58e
# current doc id: 5ef6645d-6a77-4181-a51f-15e9ee92654a
# current doc id: fa4a3495-4063-4acc-acf0-eafd2c6f5f0b
# current doc id: 7de6180e-ca7a-445f-9877-f2b91c3038d5
# current doc id: 77c34c76-c8af-440c-be05-bb7fe0d869e2
# current doc id: 6aead7c0-9231-405b-8516-783ea6806502
# current doc id: 19b917b8-b955-4afd-8880-8d604e21f4fe
# current doc id: be1fc246-88b8-45b6-be45-42cfe225e395
# current doc id: 7a018dc3-5439-4749-8792-5c6c48ab00af
# current doc id: 4961a909-7e50-494d-becd-c86d0eaec51c
# current doc id: a4a72255-9e40-4345-8e01-a472caac5159
# current doc id: 7c290468-8e37-4858-8988-8b65ebd74602
# current doc id: c1db17f5-0162-4af9-8482-a97861ba28c6
# current doc id: ea0d229a-d6de-4b23-8b0e-67a9ce47bb23
# current doc id: 0b2652fa-3764-426e-b0f9-d64eb835b11e
# current doc id: bdd3fd9c-1889-4548-b946-5fe5978d94e8
# current doc id: c3e58463-ce99-47e0-af21-323899e18154
# current doc id: 0a2d192a-cc40-4a54-9fab-f61c3cb5f9dd
# current doc id: f53a7adc-b7c4-49e3-854c-a6b4bdbde7ea
# current doc id: 4514fb27-0a0d-412c-96f7-f6c3667b70d6
# current doc id: c096ad41-f23d-47be-8302-357d1ecab822
# current doc id: 55d376b5-e405-4166-a1c5-0c5cfa3aef8e
# current doc id: ee5273d7-a6b4-4c0b-bb9c-05b2391b333d
# current doc id: 3d04d18d-dac3-4a70-815d-e9766ab3b595
# current doc id: 047aab47-3ee7-4f4c-bc01-0e54c9ba72b4
# current doc id: 485900e6-ab0e-4ad1-81fc-1e700ecf6b2c
# current doc id: def8a939-6510-42db-b494-361c5393842a
# current doc id: cb31e974-c7ab-4f4b-9fea-f4b7d476b5fd
# current doc id: 1f59fdcc-9abe-4bbc-9d1a-e1c31a2ebed0
# current doc id: 972ecab0-d936-4754-94bc-df95d2738460
# current doc id: 9ffa46bc-e6a5-456b-a969-f4846ae1c617
# current doc id: 0fe108e0-81cb-42e1-8623-9f9c475fa3a9
# current doc id: 48a5322e-d8a9-4309-8756-35b51b118dea
# current doc id: 0766c27c-2236-4208-aeef-1d39f34d78f4
# current doc id: 0c388097-66a0-4c6d-beb5-768585679abb
# current doc id: a933a777-2355-47ca-b660-cbccebf5b72d
# current doc id: b2a7e043-b4dd-4046-8f3f-44421a752746
# current doc id: 4fd4acda-b5a0-425e-b431-3f6ad4024049
# current doc id: 7861385c-5796-4ccc-8656-547b08cb1dba
# current doc id: ac99725d-c772-42f0-8300-3590e6d730c2
# current doc id: ee828fa8-a9d7-4c62-beec-06b657f14438
# current doc id: d0f09e83-f24a-4413-9d82-3ecb76f85c16
# current doc id: 6ee4e5e1-ffb1-4473-81d2-390935c6827e
# current doc id: 8d7ef24b-fda1-46ae-b2d4-9ae285d21941
# current doc id: f51b29c5-02e4-4b3f-beaf-4e6a79289828
# current doc id: 581f7087-fce8-4733-9cb0-74e72027740d
# current doc id: f0abd050-0080-4974-8a75-76a7f489ef6d
# current doc id: f323436c-9292-443e-bf05-bde2b071b555
# current doc id: 776e7ed5-5413-478f-977a-84c9bd1d8959
# current doc id: eadc6478-7132-470f-b2b5-16d8a17fd8c7
# current doc id: ae877896-0e15-4c9c-a615-521ddf896d76
# current doc id: a57f06fb-d17c-4f26-a367-c7cb73228fe1
# current doc id: ab412195-806e-46c2-b3e6-16884e589f5c
# current doc id: a976b37e-127a-4ae5-8b1d-081ebbf9245d
# current doc id: 4bb8dd44-250a-4005-9155-eb888bcff316
# current doc id: 375b5531-95a3-4c3b-bedd-db1abd35e352
# current doc id: 72853d64-e655-44e0-9b21-8a2832462cf6
# current doc id: 15d66161-3ae9-4d03-8d27-7df970872483
# current doc id: 244c42a8-40b0-43f9-9a0a-48c2fa3cfaaa
# current doc id: 733e6dad-a69b-4d8e-9fe4-0702f75ce964
# current doc id: 6752ae7c-df7a-419b-b7a7-2df324506ccb
# current doc id: f0c62896-97c5-44c0-9ccb-b634dfaa9e24
# current doc id: 25c2b735-19a0-4e8a-95a7-c55938b597da
# current doc id: 4947fcef-37ce-466b-a3d5-7fdcc6ecaa71
# current doc id: 73a89ef8-7c9f-4074-8f1f-e6fa4b380f8c
# current doc id: a65dfccb-1c2d-4889-b25c-6dbe38c26583
# current doc id: 0bdc934d-dd8e-4d70-8aa4-ecd5d74bcd38
# current doc id: e2139c38-7236-47ea-983c-fd8a10bc6dbf
# current doc id: 69c5c523-0427-46dd-8d2a-dd6b5dde453d
# current doc id: c82281ad-b695-477c-9e89-db49fc87365c
# current doc id: 1a44667f-a1c5-4046-9849-4a15225c8424
# current doc id: d984f4d3-7e07-467a-b3a8-476c30c662d8
# current doc id: 9b4a3386-299b-4381-a047-e2e4c934a7e3
# current doc id: b44bfff2-27ee-46bf-91f6-d81e4692a28c
# current doc id: 04fa01f5-b413-43cb-91a9-644df9d08ec9
# current doc id: fe3111f0-5852-4db8-ae6c-5953a86e6a5e
# current doc id: 59565068-4c39-477f-98e0-c003b8bd58fe
# current doc id: c66d8c15-ffc5-49c2-b99f-3517dc981f3b
# current doc id: 80c8ba73-82b6-43ce-b960-c0b8225102e6
# current doc id: 8047bcbc-40b2-43c1-94e6-e56f383b432c
# current doc id: 2e89e3dc-3bd6-4a01-91a6-57fc43d813d1
# current doc id: db1ec509-9205-4429-9c2c-3cb59e1c0e03
# current doc id: a92e4099-ad57-4367-a152-9c4a9c8e368c
# current doc id: 05e6edbe-01c1-417b-aed2-92f6de9e1d27
# current doc id: d88b8f1b-c952-4b0c-ba37-ca083cf9f3fc
# current doc id: cdc117b6-ac84-43d5-8165-1ac5a89e112f
# current doc id: 023be2d1-204a-40d5-9b24-6f78e2ea9226
# current doc id: bafbba69-6ac9-463c-9165-367d30a130af
# current doc id: 5a989de5-4eb6-4689-99c3-c4c7b452adca
# current doc id: 59a66c91-fdaf-49b7-a67c-eebf279f2f65
# current doc id: 84ae44fe-f667-4f6c-bf58-a1adde58651b
# current doc id: 5fd08296-7075-4cbc-895d-e235cf1a1e41
# current doc id: b10c6379-f8cc-4603-a2ca-60c0a98135b0
# current doc id: 4d70e5ca-1834-4148-a7b8-d50cfcd726f4
# current doc id: c59f1db5-550b-4be7-a673-e5a9ab2a00cc
# current doc id: b4a64e68-caec-45ec-bb4e-910d464b3727
# current doc id: 76ea38c3-e3d2-43a1-89d8-dde34b6a2549
# current doc id: ca0dc069-0c98-4625-9139-a3dc62f1d6b7
# current doc id: 181e5115-415e-45b3-ad7b-4f70ab58584d
# current doc id: 00675f3a-8aef-4bac-983d-30e93b1627e7
# current doc id: 5f8a2856-01da-4b54-af4e-017bf14db6c7
# current doc id: a59d2fce-8798-4480-84d4-c94160244988
# current doc id: 81e6c75a-1ac9-40bf-8c5d-49a967c83f3e
# current doc id: ee6cd41b-3d4e-4f46-96de-0b1b50a40a26
# current doc id: 083b671d-12e1-4f21-a89e-2ab5176eebe3
# current doc id: fe22e681-c94a-4268-9133-30d1d7269bec
# current doc id: 1df26405-7f05-403b-b812-4a96a95e728a
# current doc id: 6db2c695-827f-4be2-bb60-f47c2555bec6
# current doc id: b53d170d-6458-4877-8832-fc39538c8f0a
# current doc id: 91455198-c96e-4682-8ba8-ed53115aca00
# current doc id: 78cc8616-83cb-4f64-b7e7-c8b231ae0f73
# current doc id: 94a71ffc-49b8-4c02-a4c5-58cac3b3692b
# current doc id: ae37efff-2d0b-4976-861a-e5a6b827236d
# current doc id: 998299b1-8763-4678-ac93-c68accb69bdf
# current doc id: 13dd74e8-0df9-4af3-9763-122659c70ab1
# current doc id: 0fd70960-e818-437d-8fc2-08c7574aa0c6
# current doc id: fffe746a-d6da-4744-bb90-8449ed7b4c36
# current doc id: 661fc287-1da9-4564-a3c4-f4226f80019a
# current doc id: a9157730-16fd-4bbc-8c8f-ad9b7614a221
# current doc id: 024af948-e7c2-4aa0-8ed8-4582ebe107e1
# current doc id: 76f16f8c-b18c-4d7f-9b05-4bf2dc2c5340
# current doc id: 6de063b6-5d1d-4c79-8ba6-a47b53c24cdb
# current doc id: b55b2f2b-5ba4-419f-b9d4-0ee99c69f26c
# current doc id: 81ea1b95-e46a-42b5-8cc6-3a1176f4afbf
# current doc id: 6e47b2c0-d2b7-4bfb-99e1-e122d1896895
# current doc id: 3b5a84c5-1ea4-4da7-b20f-3739f8d1e858
# current doc id: c7fa9138-4fb7-4be8-9be5-e34871766e6c
# current doc id: dab4a175-af70-4172-85bf-1c63bda6f3dc
# current doc id: b880f09b-145d-4b04-8904-15294d602fcb
# current doc id: b33d6baa-83c9-4934-9347-11ba013ad139
# current doc id: f187291e-7d6b-4710-a07c-d4f4f173fc87
# current doc id: 1f09d8b3-447b-4550-b6c3-baf3c2bbb236
# current doc id: 2b6bd87b-2a69-4781-9611-f12dba865965
# current doc id: 55f9a18e-493d-48a6-bfbb-7e2008812646
# current doc id: d36af212-e6db-4aa6-893d-44369eca609c
# current doc id: 22deb2fe-4045-4263-8529-4833bf26726c
# current doc id: f2631761-c6af-40a0-a77e-335201b17a58
# current doc id: 3088041d-0141-4f52-9f9e-184b793b71c5
# current doc id: 246bfb87-e337-417b-ae64-8ede62e5d73e
# current doc id: 78d6cc88-68e6-4298-bbba-5c61ab91d462
# current doc id: d26aec18-2e14-4773-b238-6f67ea08f47a
# current doc id: 0fcb1497-7197-4db2-b707-d5376bb25d7b
# current doc id: 3ca33725-2411-4c41-a7ba-d876af62e15f
# current doc id: a8fad100-a33a-4063-94e8-837be988208b
# current doc id: 2e2a8a81-5f0a-47a9-812e-a55ec673386f
# current doc id: 336819f0-45b6-40aa-804b-8f1ed4221472
# current doc id: 017cedfa-ee6e-4505-b286-05e7380bd4ea
# current doc id: 509d526b-455c-46fc-b588-b8586eface49
# current doc id: db972a12-c570-410c-aad8-cb0e40972d4c
# current doc id: 0a950c6e-d039-44d5-b5a9-64b7b3ad24d3
# current doc id: 7e1b77d6-948f-447d-a1af-d34e3749bcf8
# current doc id: 5e3d2820-09a3-4bd2-b14d-34dda9f71469
# current doc id: 013b001a-0b57-4882-b4d5-80e071facc5b
# current doc id: e98db194-0d24-4f24-8fe6-afaf38f0a175
# current doc id: 21f582d3-7703-49a5-b0ed-7383037ae83f
# current doc id: 5fc846a7-75fc-4155-b627-8f4971f7eece
# current doc id: 903af13d-e03e-4e0c-8109-b57a918d0c04
# current doc id: cd5043b9-f511-41f4-b99a-49522aa6885c
# current doc id: 17b0f439-8425-4172-a00a-81271a621ab4
# current doc id: 4cf0b120-317f-48db-8092-8b090108e6ec
# current doc id: b5e8e3a6-213a-4d94-86c4-74032588350a
# current doc id: 11af0bba-5738-4a37-b5b6-887837678ca4
# current doc id: d09d850e-5ddc-4b00-8d49-7564f7cc7b68
# current doc id: fe0d0bb6-6d31-4698-9744-b5b62591194b
# current doc id: 35214e84-a754-445d-8abf-250be6006712
# current doc id: 60783c93-f4c6-42fb-9e4a-77affafaa50f
# current doc id: 17cf5fa3-3e0b-49af-9a8a-0618ab496741
# current doc id: 0f27f3ff-eba2-42c8-a7db-9539bb80841b
# current doc id: 9ebb754d-fb14-4405-be27-e48fe5f88b69
# current doc id: 12025ee3-cffd-4a3c-b47c-0a6127fe60ee
# current doc id: 09a1bf2d-66b1-46d1-a45d-1991968094e3
# current doc id: dcc17df8-cc13-4b8e-9bf8-729151f56804
# current doc id: 168f23f4-3ae0-4d0e-aa0b-c3a30221afd2
# current doc id: e1677aac-ea49-40e9-83ec-cd3082fe9ae7
# current doc id: 10d2add7-f1c7-4d1c-a16d-abbcc37227b7
# current doc id: 93834be7-864d-4dc8-946b-9c32979163b0
# current doc id: 163d2723-2911-4ac0-843c-84cbc27c6864
# current doc id: 889b6254-5f02-4749-907a-c4cc6c178f32
# current doc id: 7c66b699-2605-4af3-b9a4-e972a491fa2a
# current doc id: 09933086-a46a-468f-9afb-5a887fe9de4a
# current doc id: a5403eb0-d8fe-475a-8ef9-2a1b100e9c05
# current doc id: 18add2f5-714c-44a8-9fdb-ee4ca9f46067
# current doc id: cd556e89-56ca-48be-b8fa-891eada78755
# current doc id: 156b6140-0666-4881-87d4-3bd2698133e6
# current doc id: fb830ba2-39d5-426a-918d-c6740f483c41
# current doc id: 98f8befe-8ba4-40f5-87f1-5a12bbaa44fa
# current doc id: 1ba7cdd2-3a61-435b-bbaf-986de5b29316
# current doc id: ac9ca841-e6cc-4607-9ebd-441c0986d53f
# current doc id: 8132fc6e-02b9-44f2-b5ff-890e8922cce4
# current doc id: f4f9c21c-7927-46a2-8fa1-cd8283239103
# current doc id: ade9f920-55f2-4416-b306-9b57dbc080af
# current doc id: 477f7bcd-a672-4f4e-acf4-007f7b0e7e8b
# current doc id: d0353f34-e445-4260-b239-a505dcc47992
# current doc id: 5c0c98dc-95eb-4ee4-9a6b-0ad146da6d1c
# current doc id: cd3a0490-fb61-498d-b899-bc271fcd0acc
# current doc id: 0c4ba73a-ed34-4556-ab53-b3858c282a52
# current doc id: be55de54-cb72-47fc-b59f-815eabfe01ac
# current doc id: 558f4642-ff8b-456c-9af1-529f5214e609
# current doc id: df8ddcfb-b299-4c7f-a9ba-80120dc84c9e
# current doc id: 8ca02656-7927-4094-9e36-46fc2d5e7735
# current doc id: e4c4de8e-75f5-4de2-81ff-e280a5e082ea
# current doc id: fd5dfd7e-aa45-4401-8577-624595d43791
# current doc id: 20e59508-6203-46e7-93e5-31fd4b54f08f
# current doc id: 32280bec-182e-4533-9150-a7c99f9e71ad
# current doc id: 540433f3-ff8c-4638-b9bb-f12439501160
# current doc id: 8b5d9682-8202-425c-b073-f15ce7ee8f30
# current doc id: 6167197c-132a-46f3-987c-3b6f14907b42
# current doc id: 7b4914ac-e894-46e5-99d4-92b14f783bed
# current doc id: 7c05a564-f357-4516-b424-d6c3453d8c27
# current doc id: 6a5e5755-514c-4b9f-9412-bb14c5fbabed
# current doc id: 4731e057-6786-4f16-8673-a9e42ed79ac1
# current doc id: 90de4980-154c-47ac-a579-1ae296859def
# current doc id: 633895fd-2065-45cb-ae4b-2b55870de2fb
# current doc id: 2909397f-f4bf-46d6-a461-c10a8af8233d
# current doc id: 0cdeb308-7454-4fbd-aeb6-b49ea6e0998d
# current doc id: 608ad497-73aa-4f67-96b3-745073b38eba
# current doc id: 7351da24-7db4-4861-b507-45b3cb8fca65
# current doc id: d0bc3e99-06f5-4708-9600-2db7208d3f0d
# current doc id: 38422ff8-ab9d-4b2f-89af-63734d337fcb
# current doc id: 44e84a81-0ec0-4501-ac2a-2f495fe9992d
# current doc id: d9ad52ca-2835-426f-8d15-bacfe9b16dfb
# current doc id: e4dbfbe9-9034-43e3-9f0f-0092fa994ec6
# current doc id: 13be66c7-b6fe-4c3c-94e2-dc5df4b54ace
# current doc id: d5026e97-0c2d-4c56-9269-941e405381de
# current doc id: 07eb4131-982e-4eff-9133-7c95798b4091
# current doc id: 1b5e74bf-12be-4c77-8d31-48db3b6859ce
# current doc id: 5a8dc011-eb81-41fd-8a1e-0b86e8dc40d2
# current doc id: 66903a64-b6fc-4799-815f-f6f40d921838
# current doc id: aa06626a-cd10-496b-897f-fab64452434a
# current doc id: 58c195bf-cb62-413d-8d0c-8893cc7441b5
# current doc id: 5ac78a52-9ea7-4c5d-b354-82a0022b02d2
# current doc id: 3a49b843-0f86-4bad-9927-4c82c29e33ef
# current doc id: 00762297-ad6f-4c77-92fa-0d28732f1d34
# current doc id: 5cb58ffc-77d0-405b-b483-3f2c3752f29d
# current doc id: e9e62822-ecf2-4df8-83a9-bf0452675891
# current doc id: 87c6674b-3dd4-4cf9-be51-6eb3685c135a
# current doc id: ead092e3-72dd-4957-b38b-81dcd1a2ab80
# current doc id: c3a8a434-c5c9-45f2-a93b-c00b05067e3b
# current doc id: e3f3ba78-9139-4609-a76d-b8dcff469383
# current doc id: 7a2cffab-b54f-44f5-a91d-1e5cc93761ff
# current doc id: 9d1cfb7b-5e84-4aca-a013-938cfe96c05d
# current doc id: a93e845e-56e0-408a-ae3f-b9f72065f4ad
# current doc id: 4f7e96d8-b184-4024-9c0c-b2427586d899
# current doc id: feec018b-2793-4bb0-b5d0-67be4f3d4be1
# current doc id: 805da1a9-3942-4cf7-9438-9502d75da68b
# current doc id: 579090c6-edf6-45e9-80c5-a7537d3fd8a9
# current doc id: cae2b537-e19e-4890-abbc-3c95215cc3bc
# current doc id: 9ec72223-167a-4c26-be9a-6bc963ac7244
# current doc id: de6bdee4-bce3-418f-8bbf-1a527d50335f
# current doc id: 42d3f770-72f7-4c38-bb1f-0fa838d85342
# current doc id: 80bc3dff-ce2c-4566-9891-91d4363b87b2
# current doc id: 151a1165-5d3e-47a2-97df-f732ce6fb70f
# current doc id: 758e96a9-4324-4cd6-a813-76c4672239dd
# current doc id: 922524fc-b5e2-4456-9970-c98721f08b9a
# current doc id: 2b76ad5f-bbcf-49fd-a79e-cd4a18915cde
# current doc id: a7cc6ff9-6a61-490b-b582-5a0c06eec037
# current doc id: 8db04972-fb99-4b24-9056-327d850c0226
# current doc id: d8c2d952-4a64-4f04-be9f-c7aff603f776
# current doc id: 57f92bc7-fb5b-4823-9a68-c892c2b55f54
# current doc id: c1251acb-8e92-4dc0-b659-16a0d39ef6d6
# current doc id: 4777e9ae-56df-452e-a6e5-792f8c44f394
# current doc id: 05328c1b-d74d-4166-a563-952132658f5c
# current doc id: 474d2bcc-ff40-4d73-aad8-e5aeeffe2762
# current doc id: f59d896d-9a85-4510-bf5b-2de6f0859e75
# current doc id: d4c71db5-ee97-465f-a7cb-7c8534d2f802
# current doc id: 8634b524-bfa4-47e8-8d7e-3e91a70a2421
# current doc id: cb140b48-1fc0-4678-8762-1bc88c43d436
# current doc id: 0261daf6-8771-424b-a6e9-541671036408
# current doc id: f6d3f2da-1f3e-416a-a279-ae73aa517d76
# current doc id: 50c58c02-5b4d-4997-a816-2be69cd715ab
# current doc id: a3cddff9-6bd6-4c60-8062-ff7169ee0bbe
# current doc id: f0f439c8-61a0-4294-a8cd-1bd614cfefc5
# current doc id: a5886cf6-a289-46e1-9b37-c3aeaa708430
# current doc id: d352e397-648e-45a6-88fd-eaedcc0a5d74
# current doc id: 44742fd7-eaeb-4b40-a68e-c9b6fefa6222
# current doc id: 4f31af47-8259-4c73-af0f-f89399e7fbab
# current doc id: 140e10ef-b60d-40ba-8681-4c8939c496e9
# current doc id: 7e804eaf-a9e2-4074-9a9a-7950a6b06859
# current doc id: ca288ddd-e3de-4e5a-84c8-c78e79d57d27
# current doc id: e4200cc4-fccd-41ef-a021-a61e2a545d98
# current doc id: 3e1c01ff-fffd-4886-af70-0f38c6fc494a
# current doc id: 3dab1431-6107-4308-9641-84c7c12f0522
# current doc id: 2abef4ec-4cf9-44dd-9674-16cc9b650277
# current doc id: 1cf075f3-4113-47b0-b192-15eaef701281
# current doc id: 261468e5-75a3-4f11-bb40-f275654090f9
# current doc id: 1ba82ff8-cf69-4bcd-b630-1a4c3a317892
# current doc id: aa75d76a-678a-4f4d-aa14-6169d462376b
# current doc id: 62ea7453-8fa8-4b2f-a082-6a51186b0400
# current doc id: 43395300-3ca3-42a6-8d58-61089d0dbd9c
# current doc id: a75e8118-2220-445b-a586-ded578bf0d01
# current doc id: 9c4323f6-2a31-4791-b7fe-f30d50c28e3d
# current doc id: 53d4a0ee-c0c3-4a7f-bb63-3f824cb00a09
# current doc id: 7a493eac-68fb-412c-a154-102d9c546a99
# current doc id: e8937213-7706-4b67-807a-c624c305d771
# current doc id: ce531409-f4d4-450c-807d-66d58547e4e7
# current doc id: e4b3b81e-1f72-4b1a-bb10-7f67b827a61f
# current doc id: 12001e5f-f7b6-4caf-b777-45635fad7169
# current doc id: d3fa32ba-099b-4850-b453-94d2f8b42a3e
# current doc id: 48568d72-8189-40d1-a55a-e6942a2db145
# current doc id: dd3edf9a-4b6e-425c-9595-4abf989d53f1
# current doc id: 454d5253-a386-48fa-b99c-f2057468ef54
# current doc id: 086461be-ea4b-4108-881f-5c46cf83e751
# current doc id: 793ebcf8-3c9b-4548-95c8-c368bec8416b
# current doc id: e2611966-4b5e-453c-8be8-5badcd279574
# current doc id: de84f037-f502-4580-8898-40bfd63110cf
# current doc id: 06e1202d-4894-4c4c-ae21-353054b7aa9a
# current doc id: 43d4c764-5678-4d3e-8189-b6497d2c107b
# current doc id: c3c51024-1005-473a-b793-6486ddd623f0
# current doc id: a298babd-d71a-4e65-8c1e-f678d8c11fe4
# current doc id: 30cd01ca-90ca-47d5-ba23-b372d89fc23f
# current doc id: 4dda04b7-ee17-4b61-8059-2651a29967bc
# current doc id: 0f220661-d9cb-49f2-90da-45485b029969
# current doc id: 7af3d77d-b45d-4a01-b005-e54494c779b3
# current doc id: 5dffad73-f3a9-4bc8-b960-f4b315635a42
# current doc id: f32c730a-bfd5-48b7-b89b-898361f2d9b1
# current doc id: 3a88ed51-aa33-452f-a144-9b7d1e2d5c9f
# current doc id: 50bcf16f-e34a-493a-947a-645602b66286
# current doc id: cc2aa338-2cc5-4466-8ed8-692a8caf58af
# current doc id: 8b6117af-562b-4d62-8ab3-598cf90b91f3
# current doc id: ac724fb5-462d-4e05-8443-bd5199372b66
# current doc id: 0199869f-c994-4a02-989b-b7de0c5f3b4e
# current doc id: adb82bb4-c300-4ae9-9b26-673b2cc744c8
# current doc id: 074a585f-f7a2-4898-b9ad-b906ad9ae883
# current doc id: 2ed58689-0a8d-43aa-9889-f4e4fc8fa35c
# current doc id: 15a8113c-0e76-42f2-8a13-eed5f7f9535c
# current doc id: 6e9aa6b4-3c4e-4430-be0e-918c62bbe4ff
# current doc id: 1eabc8f7-4911-461a-b69b-18d2b8b60dbf
# current doc id: a5041111-ae09-446f-a16e-b64c8fed8457
# current doc id: 4fd2b9b9-29cc-4f26-b8be-018779f7c564
# current doc id: b526510b-d986-4122-a223-003af9561cd9
# current doc id: 8a53e2c8-7a0f-42c5-b44e-26ff37b1477d
# current doc id: 24c5c722-cf20-4a5e-8a51-001960612bb1
# current doc id: 83b140ab-03b6-4d9f-9e53-c7f56ecccc44
# current doc id: 1e848182-5f03-4525-af2d-dd3d0c73fe51
# current doc id: 3f0897aa-75f2-491e-a8a7-48830ce5c014
# current doc id: 6f0e2a18-611b-48be-b9d2-284942da5396
# current doc id: 4bdc1b2a-056e-4b91-89c8-f517f51c95fa
# current doc id: e1ea7dc4-a91a-48df-b4e1-5aed8e09dfe3
# current doc id: 2980f174-c61d-48e5-abf0-99e00b11a3dd
# current doc id: ef383db1-3ea1-4abb-8fc4-8c104d8ba359
# current doc id: b43267af-771f-472e-aacf-b78d5a1b34a2
# current doc id: 9fb9ea20-6141-43b8-b28a-2bc38f0c0850
# current doc id: 58f61a27-d8e7-43f5-b697-6d49e1ae56d9
# current doc id: f805fb6c-e1f8-47df-a4e8-2303c35bcf46
# current doc id: a40ce250-cddd-4d5d-9bc8-521d86ea8109
# current doc id: 58e555c0-c122-420c-8cf0-73c927828ea5
# current doc id: 0516c11f-f9f7-4fc7-9873-92a8704416ac
# current doc id: 9493900c-781f-4e30-a826-24317d0c0cc4
# current doc id: 2fee02a1-b59c-4cf5-9ec6-9bc09b8927f1
# current doc id: 1b913363-ad77-4293-be88-b917fdb8d8c3
# current doc id: 86707b97-32e9-497c-930a-2d7e9590d735
# current doc id: f824cd55-5a7b-4ccb-8407-1feebe70de8f
# current doc id: f8ffbcc5-bec3-45ca-b90a-ea431488779a
# current doc id: c4248b1f-fdb8-441d-8c87-0329d16f242c
# current doc id: ac786acc-47cb-4099-a348-89d0782f36f3
# current doc id: c7a41fa5-6dda-4b30-9c55-170d26e0c090
# current doc id: 3b571324-d03b-493e-9c76-1bc7595bfebc
# current doc id: a3959e78-e3be-465c-9330-817b969a8e42
# current doc id: da924f70-ea48-4b70-98bb-238d552340cf
# current doc id: 9d984cb0-fed5-4c81-b59e-ced4b9977503
# current doc id: 9aedb897-638a-4f2d-9e56-95a0500e00a0
# current doc id: 18695631-edef-4486-8adf-f967c1ceb7fa
# current doc id: 4a5d720e-e028-4450-90c4-d647e29bcf87
# current doc id: bf10fa5f-7b2b-4ec4-ba02-3d29dcec55ed
# current doc id: d30a7595-68f8-46b8-b038-831589f87b98
# current doc id: 89d458f4-fabe-4fd5-8f19-a98cbad97663
# current doc id: cee07283-fb09-4448-b157-7c083d55501f
# current doc id: 6e9ff22e-f344-461e-8a70-9621104dd1ec
# current doc id: 2939ea43-f515-46cf-b71f-3d20a073b45d
# current doc id: 5e5f5e9c-7a3b-4943-8ea3-228bcfacb81c
# current doc id: c7f19478-d01c-4caa-a174-51f20542837c
# current doc id: b62c2033-39e5-4e0a-91a1-f56a606335ef
# current doc id: 629e38d3-7240-483c-a58e-a13ea3c78ea2
# current doc id: 0b0d2a3b-befb-4cc3-8455-58f030dc94e2
# current doc id: 492b06ae-6b94-41a5-9bbd-b34f53e1603b
# current doc id: 6415d6b8-e4a8-4610-abf8-2e173536e6b6
# current doc id: 9c0ddd58-2b60-4ce6-b376-273457a4bd4e
# current doc id: 7ff94118-e0bd-46fa-b9a5-2e4666562d2f
# current doc id: 18f23308-a09f-4543-acbc-2f4811247b00
# current doc id: 80081060-9c8a-4bbb-8b12-35299a73f1b4
# current doc id: 1cb75bb2-d620-4193-bcec-72c069adc886
# current doc id: 4a7e9003-0b3c-4166-bb02-d7b344ff2d22
# current doc id: 1d8afeda-252f-4135-8dd1-df9eb8150b46
# current doc id: 773a84e4-6454-48cd-8e45-e29fbd6107ee
# current doc id: 1d1a3a22-7c51-44cf-a8c9-55724352d09c
# current doc id: 982493ee-ab8d-49f2-bb00-cf936958ab83
# current doc id: 59282daf-b528-494a-bbf1-883d540e156c
# current doc id: 43d53572-e5f4-4d6e-8fb5-8e8f9b6fd12f
# current doc id: ac770a08-a271-4915-a635-51e932e3a80f
# current doc id: efcb5a0e-b65d-4d68-8429-670d50fd135c
# current doc id: d32e1576-a3f0-4a20-aa5e-7bc729847b76
# current doc id: cc66fdcc-210b-480d-bc03-6677d7fda6e0
# current doc id: 01c889f2-b5ed-4c36-9d51-3f4f2c2be483
# current doc id: e78a0dbf-0c69-4104-a1de-e225ebf1db11
# current doc id: e4625b70-c13a-4d10-b1a8-5f44ed7341bf
# current doc id: aae289b0-b704-4e6a-a421-7a2fd85ca026
# current doc id: e96f3762-26ff-49d8-96a6-a39381f5e5be
# current doc id: c02498b9-8267-4c85-a73f-885948674752
# current doc id: 9c354d7d-353d-4c9b-9726-1c12b5c073c6
# current doc id: cc8a63d8-ce35-48d8-baea-703e0413d169
# current doc id: 76bdb4cf-01d0-40db-aada-8e800895015d
# current doc id: 6802903f-b99a-4e2d-b6fb-91add48e11df
# current doc id: 5fcb3007-ac4e-4a05-9b9f-3d94a84860ea
# current doc id: 50193c25-02be-4cee-893a-ef3490fc9355
# current doc id: 4a1a291a-a285-471f-a886-266a3e5d66c5
# current doc id: 9c5b85cd-c7e5-4cee-a86c-f781388986d1
# current doc id: 331f0cc6-69ad-42fe-92ea-01eabd258900
# current doc id: 1fcf8be0-2dbb-449d-af81-0d4502b253d8
# current doc id: fa990fcd-61e5-4c0c-906a-676dc78bf44a
# current doc id: 8cc92acf-6b20-4d2e-8e94-3b5ac6ff85fc
# current doc id: cebd132f-0b6b-4c16-a440-82e10f5941dd
# current doc id: c133116b-38ea-4cc7-b38b-5b3fdf5c7e78
# current doc id: 6b02d97c-4937-40ff-8e5f-7b2598c7c5f3
# current doc id: d4677c0d-bf82-4dcf-99cd-b78555c9b806
# current doc id: 4c6a4a17-7e25-4f95-bcde-80f2254840d7
# current doc id: b7cfab24-c1ab-4a77-aa90-7d3596ef1607
# current doc id: e6db904b-59d1-4c9b-8c4e-eb696beffc5c
# current doc id: b2109a7e-23ae-40c1-9bf7-c95282b411a2
# current doc id: c99daaee-f66a-4765-b2b2-627bb9ca8cb2
# current doc id: 36083638-49e3-48f1-86f3-566b3c6967b8
# current doc id: b9197a7f-0f48-4a0b-8910-ef05fff1378a
# current doc id: 6c69f669-cc75-44c0-be96-b193ea34363f
# current doc id: 5e67bcf7-626e-4449-9015-30448b692177
# current doc id: 85a3a472-e89f-42df-871b-f29823c72c16
# current doc id: d4abbc40-f71d-43e5-b895-d840047d7a29
# current doc id: 5486ab49-7740-4457-87d2-f964d23bf661
# current doc id: 7cea9349-fd8e-435a-8c08-9992736fdec6
# current doc id: e5a30b6a-ef42-4a36-b30f-09226e0271de
# current doc id: 3d3450b9-d7c7-42f9-a65f-75e9b4443e6b
# current doc id: 69d232da-7947-4190-ba4e-ec3976342100
# current doc id: 09c3a6bb-f72e-4402-9e62-f7055644ff21
# current doc id: 0d8fa32c-223d-44e3-a689-2867092d1434
# current doc id: 94bc9b42-aa32-490f-834a-a40aa2024870
# current doc id: e68ca6b7-6441-40fa-833e-d7e167a745ab
# current doc id: 02ef84ac-e4b0-4b93-af1b-e312024c4636
# current doc id: a16e0c65-022a-4ea8-9482-3cb1649adb0c
# current doc id: 5f3af9e5-479d-4f81-aee0-21ce3c9a84f1
# current doc id: 4d4494a6-8769-48ff-acb9-1eeb0fcdf211
# current doc id: ebfd159c-cabd-421c-b7c0-8fedb5fe4b54
# current doc id: ba490858-79de-4225-830e-5e8fde460505
# current doc id: ca103221-c0cd-4285-9001-96a9cb3e25d1
# current doc id: 21493357-68dc-4c3d-ade4-c20babc379aa
# current doc id: b50283b0-0cdf-474b-8aae-8643c8887e62
# current doc id: ca379635-3765-407d-8caa-99233351f2a4
# current doc id: aa7fbdd5-b8ab-4e48-bd96-6a67906f563e
# current doc id: a3fdcd25-e80c-46b2-a675-2809b19adab9
# current doc id: acf184a0-b1de-4829-a9e8-ee34ef707f7d
# current doc id: 08056178-ef35-47fc-9f98-5ef8a31d25bd
# current doc id: 444de2b2-89cd-432f-bc45-15cfa595180e
# current doc id: 0068a4ce-b461-4131-8c08-435f7cda01a2
# current doc id: 13d457ef-cf8e-4659-b53a-8f679d4dfe0a
# current doc id: a92e6a6c-e507-49e8-b11f-88493a3b6c4b
# current doc id: 5d4f0db6-6e07-4ceb-aea3-84d8fba657a9
# current doc id: a6b2376b-b52f-433b-8f80-9488d0048ac6
# current doc id: b6181b10-88fc-4486-8534-da7e9811da03
# current doc id: d1e564d7-e593-43fd-8304-b87ef92afb09
# current doc id: 8f8b3a0c-e921-4603-ae0f-4f024f2c9351
# current doc id: ffaed2fd-4411-4a93-bba9-4f095d68f1b9
# current doc id: 54e0c044-be0f-4039-88b3-8520b1615761
# current doc id: 6c7c08c0-0655-49df-9628-30b14f6ef83e
# current doc id: e8684bb9-7c0b-45bb-8bc9-d39bbf8cf413
# current doc id: e878a0fc-d5c5-4a02-8b9e-d3099f2bfecb
# current doc id: f683ea9b-f6ba-42d1-887c-36cb441a2027
# current doc id: 44b01652-62fd-48cb-a0e1-935ab086e4d1
# current doc id: 81055dd5-38e3-4478-a1ed-5fe063bdfb32
# current doc id: 968a611e-3c79-4575-829b-be9c02096543
# current doc id: fe5c1c57-6cfb-4aac-8f13-a89449b6a0e4
# current doc id: 6a63a2b9-796c-4594-aac6-d03dc2eba12b
# current doc id: a3befa29-e52c-496e-a7b5-8304423d5f74
# current doc id: d6240a09-26b9-40f2-a037-41af3cf6b661
# current doc id: 51d2c6f0-4020-4f82-abf2-732f656c3426
# current doc id: 48bf6b3c-1bf1-4c30-a014-c09e6a0f7453
# current doc id: 1dbf1e37-3624-4e4f-bd00-3e4a75c317c7
# current doc id: 6ce11c8d-3282-42dd-b68c-abec18d880db
# current doc id: 363cb44d-9292-4e54-b881-7fe8927b8255
# current doc id: 71100ad7-7934-4727-9af3-49850ebec938
# current doc id: 602d32d1-56c8-4d69-8708-ffde097d0ae9
# current doc id: 01344011-c5dd-4922-93c5-a2c84d3c12b7
# current doc id: df13125f-c937-41de-a903-4c2377cd8e94
# current doc id: 3be4244a-a8d1-4c5d-9798-a2ce9ff7a27a
# current doc id: 4726796d-c600-4166-ac36-7b97c3ab9335
# current doc id: 39210cca-e878-4b1a-afb1-15099b016a63
# current doc id: a396a262-55bd-4b96-b02a-1cfb9b407ef6
# current doc id: 64f734e7-c70e-4851-bd4c-da18ddbbc446
# current doc id: 60265f7e-b464-4294-9999-742bb49c9332
# current doc id: f9cb7288-ae83-4c92-b9d0-4074f4d37d98
# current doc id: c24bbff1-3e2d-4312-8f3b-e470d72624ae
# current doc id: f18e4cb6-a741-4f2c-ad33-ce2f3ecfd243
# current doc id: f9f4c870-535e-4646-aeed-d0cf0b3792e2
# current doc id: 8ddd711e-cfb1-408f-8f21-64268491d0a6
# current doc id: a6def96f-e673-4066-bfed-dd9901fd474b
# current doc id: 50af90bb-a8bb-40cb-9d77-723747f80e07
# current doc id: 50d1a174-d65d-438b-81d9-e972ea9e2b98
# current doc id: d6af303a-3ed3-4ea7-ab7d-7878a2c4e22a
# current doc id: 42f31dcc-ce99-4f69-b263-48c7df884cc4
# current doc id: 475e3623-eb4f-49ed-ba83-dd9d95af0081
# current doc id: c0d40eb9-582d-4785-b574-974c3f344f38
# current doc id: 255d595c-f19d-4430-802d-d1c96b61b829
# current doc id: e94712f8-b2e8-4750-8545-5ba79106e237
# current doc id: 98877950-0be2-4930-a36b-81a1888ce51b
# current doc id: 2715f2e9-65c6-4915-9a52-8de87dbd1bb4
# current doc id: 21c3d288-bd6f-405e-b1c2-b8e041aa09ef
# current doc id: 723d6d27-c9d8-4d50-b5bd-c977d1f649fe
# current doc id: f0cc5134-7904-43df-80dc-8b67a6ea5ea0
# current doc id: ee0593f1-d54e-4e63-b761-efe1dd487729
# current doc id: efe2784b-69cc-45d3-bf3c-8c8364fd427e
# current doc id: f5457601-109b-4e03-b3a2-256a32153d0d
# current doc id: 22abeb7f-48ba-4871-97e3-dd309b2b2bbd
# current doc id: 7821bfec-d7c7-4675-8d5e-54db3c5e8ba0
# current doc id: 7365fa6d-8b9f-43c5-b2b1-9d9736808d91
# current doc id: 1ca0c38b-2764-470a-9724-88d038c1aa84
# current doc id: 45099b09-e055-4e18-90b5-d7de6f2524ca
# current doc id: c82071b6-cc4b-4f5e-9ac6-e2f56725a50f
# current doc id: bc02a94e-196a-412b-ac12-931f27e5d9de
# current doc id: 34ef50d4-1c41-460e-b19e-debb177fbf4b
# current doc id: f1c002a3-d7f4-4ba3-8e48-1ecf1055e1e3
# current doc id: 6de621fb-7bad-42e5-a444-9e0825fc9bf4
# current doc id: b526e4f4-916c-43c6-b453-6bc0b65028bd
# current doc id: 341de2bf-2b57-474c-80a2-c71235a92bc3
# current doc id: 51971add-7d42-4c00-be78-1e9470bec3cf
# current doc id: c1980c79-b121-4b96-9480-b54af03cc535
# current doc id: 02787fdf-affe-4314-838c-e558490438fe
# current doc id: 4e950e70-2193-440f-aa06-6f922fdaf74f
# current doc id: 1cbd5808-b3bb-4f53-bef4-0775ab1f990b
# current doc id: afbff39f-64a2-4a60-a886-b5a47ed4a895
# current doc id: 126d1af5-59cb-4177-b2e9-d2bebd2544e9
# current doc id: e01961b5-3f49-42e3-9295-70e0bb192662
# current doc id: 36883cbb-f30e-4d72-833b-d26d8f354515
# current doc id: edad2f14-ecdc-420a-9a1a-a2102e2ad9cc
# current doc id: 6ad77700-fe8d-44bc-ae45-a680fa61d931
# current doc id: 333bc875-42d2-45eb-9afa-40444bbf9abb
# current doc id: c25c4881-6342-4512-97d4-da9895cd492c
# current doc id: b7c2e7d8-8ee2-407e-bf93-f3bff5844020
# current doc id: 2b076558-a1a9-4ec9-b862-a56d0acd0cab
# current doc id: dfcd42e7-3dad-4de5-ac39-244647580981
# current doc id: 8c234073-f533-41c9-bad8-abe303f1596d
# current doc id: 17ee876a-0587-4ffc-a338-e0ea9714c962
# current doc id: 0c596bad-46b1-4be3-b1b1-6359e07b2558
# current doc id: 25b820ef-2de3-41b5-9f6d-bdeb69cbe856
# current doc id: 9d512498-1501-4ae3-90ab-1a60e7118c1b
# current doc id: 2eb90c7e-7777-4907-bab2-0adbe90279ec
# current doc id: e370882e-cc6f-43cc-85c2-ed1801354af3
# current doc id: f9ba5a01-869f-482d-b803-2e8d1a6c54f2
# current doc id: caa92d54-6245-41df-9eac-f65daa039ea4
# current doc id: 1b501426-bf1a-4c07-b78d-b240131b283f
# current doc id: 3194fc9e-b8b1-4e9a-9a30-0e811b681903
# current doc id: bcc016f9-fe56-471b-bec6-029233466009
# current doc id: 111d41a5-9eb7-4611-a7e1-c35ed2ef329c
# current doc id: 33ac20ca-d9bb-4acf-aec0-22e7db54a73f
# current doc id: 9be277d5-4baa-4ed6-ac9b-7373a57fbe00
# current doc id: b1ef092d-65b6-485a-82b6-771b0766ed16
# current doc id: d7785f52-2706-42d1-a860-699845e27c88
# current doc id: a48daa28-f125-4d77-96a8-8c02b60516b4
# current doc id: ac5c5ae3-a214-42f8-8be9-4b2ac5b63993
# current doc id: 9503fb28-98cd-48a8-a3e7-a7bc73de5ce1
# current doc id: 685deb35-c142-4b04-b7e2-f70eae07c96f
# current doc id: 76e301a8-d982-4e12-b441-c279f9245c30
# current doc id: e698481d-6475-4e9a-b245-5ae94dc0aa52
# current doc id: cafea6c3-ee81-4371-ba8e-ce80d3310d29
# current doc id: 3975f87c-4d7c-4f66-a4fe-c2152d3a149d
# current doc id: 4a077537-49be-495f-9994-efc6450c8f83
# current doc id: 86cb2bbe-8e99-448b-8ccf-7bd677c75ca6
# current doc id: b9509806-77b6-4c9d-9aed-3c331721fc1b
# current doc id: 91b56e86-ce49-42d8-b747-2bd6e39b9115
# current doc id: 2cac2ec6-8d3c-4ff6-b1a9-19a51d586a2e
# current doc id: efa496ae-6779-48cb-9512-63e34c9a756d
# current doc id: 19dd6bcf-f178-494d-80d1-cd8549125e91
# current doc id: e9e5061e-6c3b-4796-b14c-65cc796e21ce
# current doc id: f59ea31e-7bdb-4bca-9117-6f305dc2d2d2
# current doc id: 452940bb-180f-464b-9f47-d3f02d956bcb
# current doc id: f35f5b04-c6a0-4eb5-a5fc-ef049d2071e1
# current doc id: 7c7ba905-3ac6-40c4-ad0f-7f494068d750
# current doc id: 102d4966-59d8-4aa7-a977-2d62d2ae199a
# current doc id: 6a3280b7-0184-44be-9926-0e45eac17a9c
# current doc id: 01635aad-7478-4605-a546-27ba9dc676bf
# current doc id: 2a1a2bd2-e0e4-4ce5-9054-eeda13b642d8
# current doc id: fa2a0814-6d82-4f98-a673-a09035a147d2
# current doc id: 490cf902-bd82-469f-9946-10c434fa30ed
# current doc id: 2139cf40-4e0d-4ba2-9fe8-81eea10f5819
# current doc id: dcc22392-23cf-4c40-880c-bccbfe677c67
# current doc id: 9768f433-d5c9-494f-8797-a70cbafaffee
# current doc id: 75d4875e-a6c6-4643-a6d6-16eb57ff9904
# current doc id: 2782b73a-021f-4c98-9a2d-12802b7a8d0d
# current doc id: 5134758f-8397-4fc9-8746-2c5da8f1b26e
# current doc id: 049d6901-5777-466f-833e-ddf9f804a103
# current doc id: 90c71cd2-0078-4c38-8e8a-4f27d54b804f
# current doc id: 22ed937b-fab7-47ad-8364-9c88c923e681
# current doc id: e31ff538-7b5e-4125-a244-11cae1b8a580
# current doc id: df5087f6-d1a2-4cd3-b7c9-d8c9165a08dc
# current doc id: 94259d60-9af9-4c3d-b759-d93e75177888
# current doc id: ac6c2aeb-6ce1-48d6-ae43-6cc92e4d1062
# current doc id: 30f70331-1df3-4dad-aebe-62ab76070dad
# current doc id: 0b9728c8-194a-4ae6-8e0b-2f667382c315
# current doc id: 05d3c191-2476-4d74-9355-9a60414ca0fd
# current doc id: c3758302-146d-499f-be6d-d870693032d8
# current doc id: e37863b2-86e8-4198-8251-7e6648480d72
# current doc id: bee741c0-597c-428f-b605-b9b55c0585ef
# current doc id: d1aae2b7-e6df-480b-9fba-657b211ffdbd
# current doc id: 4fcf9f73-62a3-46bc-9d27-16d84d534245
# current doc id: 028cb5c8-0640-4a53-8152-435d70c6d8aa
# current doc id: 7e8fb945-569c-4e35-8c8a-c2c6e4c4dcac
# current doc id: 7e1b3f34-2447-47b6-b9ea-2c381d1c1ccf
# current doc id: 8563344f-6576-4c3a-956c-e2e8cc74a4e6
# current doc id: 4f0f0edd-ac76-47a6-87cd-a5b6dde40ee0
# current doc id: 70e6e86c-39aa-4d06-bc27-ce0b06b857e0
# current doc id: 9005a2e5-7b28-48a8-a9e4-a7d64e483ece
# current doc id: b9bd18de-27aa-4183-9c8a-3abd5bf44eac
# current doc id: 28139f0a-c001-4fdf-9340-c1a08205f34a
# current doc id: 6b3130ea-bb58-49e9-b4a0-5a0878ef62c4
# current doc id: 1eca7ed0-b2f9-44a9-abc6-c599aa1f2023
# current doc id: cfb0dc65-6836-411e-9f70-ad67c4f482bf
# current doc id: 105142dc-d397-414b-9004-905367df5b1a
# current doc id: 1f1d9ad5-0431-43cb-b513-afc6695ce53e
# current doc id: b6512ffe-f49f-4b9f-a0ce-775aa3467177
# current doc id: 9b50b66f-95f6-4dea-b592-8c787322b598
# current doc id: e4cc5677-6639-4b5b-b61b-61fc5cfb9c5e
# current doc id: 8d069f77-acd7-4091-85b6-20cb90a82af6
# current doc id: 048f2a0b-7353-4876-a177-4d6d9b95d7bc
# current doc id: 64d403f8-dd87-4535-ac14-b7659067a316
# current doc id: 269a93ec-97b2-4285-bf92-9957a83c30d3
# current doc id: 63ed1651-a80d-42c7-b81d-80dd2a469b0f
# current doc id: 46154400-1509-4939-af0f-7d8a50576697
# current doc id: ec9b39db-7e2f-4666-bf90-6ae136fdc1c2
# current doc id: 3c6a3f00-7dab-4a0c-a260-8b1a09f93ce7
# current doc id: 4931e162-4db9-45bc-ab4a-8e27a26ec747
# current doc id: d561a996-293a-482a-bfb0-8ecfe5bfae4f
# current doc id: 8b7f362e-1b3a-4175-a24b-76c532b3bcb0
# current doc id: 4b066104-1200-4084-b3c5-01281099cd31
# current doc id: 84a71e7b-25f4-4df6-91d7-15616dd926d7
# current doc id: cd2e1b63-c0bb-4d52-9f8d-15736210a7d0
# current doc id: aa0fbbf4-c3d8-4623-b1fc-a1ccf42bdf67
# current doc id: 12bd941e-e778-4c71-85a0-f15fb6a72260
# current doc id: 63079e47-3095-4939-be1a-21490f44d586
# current doc id: ed2692be-5a81-4874-9523-c19579ac51c9
# current doc id: ff7184c6-2766-4519-ad06-04c79a969ef6
# current doc id: e1816c6a-feda-4805-87d6-b1f416112030
# current doc id: 876b9dc1-c202-4e4d-b840-ddbf963c25ae
# current doc id: 2bfb4b99-5dfa-409e-bc36-e6bc128d9101
# current doc id: 40b6257e-7792-4edb-a5b8-d2e638da76b7
# current doc id: 2e1f578c-0fd0-41c0-92e9-b05c9c34b8a1
# current doc id: 19a39f5f-795b-4c89-be5e-81fc13efd67d
# current doc id: b939942d-9dd7-49af-9796-cb74cfbecad6
# current doc id: 7bed2fd3-ae51-4a41-ac9c-ae7a8d8bf7bf
# current doc id: 22ddf389-2dc0-4cb7-b45e-c18f676ebc15
# current doc id: e8ea9af4-74be-4c65-a058-a0af3256bddf
# current doc id: 10c9da59-be17-4279-8529-ab6f6acaa706
# current doc id: 6da4dce0-f157-44fa-b43b-3fd29d4b9ef4
# current doc id: e533bf7a-acee-4f08-933c-9d93817bf0b1
# current doc id: 9728eedd-1ac8-47ba-a17d-06bd9726c146
# current doc id: f38addf6-95dd-423a-9277-5e4c16017004
# current doc id: 630dd6e3-bdee-47c6-9544-953299042052
# current doc id: bde3bf9f-d505-4b0a-ae0a-f35246bfcd20
# current doc id: daec8b62-ecfb-49ab-9de2-ffdef2b75cc2
# current doc id: 48653d75-fddb-4a9c-a0b0-8214ca48409b
# current doc id: 79ad3dee-4f44-42d1-a2f1-2990ecadb5b0
# current doc id: 931992c7-82da-4860-a95f-6bda962fb1eb
# current doc id: 5fd2da41-f31a-4147-bcd7-aee4b9d1b952
# current doc id: 37684f6c-9ea6-4121-a320-e8cc2a04a05f
# current doc id: b6cb18cc-d517-49f9-969c-1c1d1f191398
# current doc id: a3822595-fc54-488f-a28e-33af5b673103
# current doc id: e28ade93-1c18-4766-aa97-6a8c4e095fe9
# current doc id: cb02952a-5bfb-4fd1-ad00-4e5dd58376f6
# current doc id: 80e02bb6-e4c6-4949-a427-4521e8430922
# current doc id: 6d9b12be-1d6d-4b7e-b008-f1b58030ddc2
# current doc id: b1b9dda7-5804-43e3-b4fb-7eddab92b374
# current doc id: cd037ec6-2e03-4df5-8011-12ccab8e9a4d
# current doc id: 7bad9790-5cd0-489c-8147-e164cd623f8e
# current doc id: eeb11e81-7827-4767-a226-4bd2faf92c2d
# current doc id: 2f48ad72-cb7f-4c08-957b-26758bf99f2b
# current doc id: 18e02489-6638-4d60-8d2b-71910107dfd5
# current doc id: f114a686-bb6d-4957-b390-46fc2a4d68cc
# current doc id: 0f32ee79-4a0e-422b-b55c-69d6f162efe9
# current doc id: 7974fe80-8a9b-4a0d-ac1a-c60766bfc029
# current doc id: 93432930-93ac-42c1-93c8-ecb3d62ffcfe
# current doc id: ee9c766e-4872-4212-9aaa-122f532005de
# current doc id: 1fe97601-7a89-47fa-9788-ca4740328310
# current doc id: 651320a5-af9b-43c3-8eb0-09b0e890e9f7
# current doc id: 73ce841a-c83a-4fac-977c-5291ecd4197d
# current doc id: 0fce0ee6-adf3-4a61-883a-1cdf615136e5
# current doc id: 60f5ac6d-11fc-4c26-8595-1801168b2623
# current doc id: a2eb693b-227c-4bb0-aab1-02f10d33f25b
# current doc id: 72376db4-89fc-4690-aff0-3f7df6dbd6f9
# current doc id: c9a2edb7-3d05-472a-b023-a040adc041c3
# current doc id: 99f64085-d0c1-4d43-8f9c-57f9aeb83895
# current doc id: 12c143f0-105d-4930-a967-8753ab272f14
# current doc id: 93ab7c19-6e2f-4a79-ba83-12cbb68da42b
# current doc id: 380c91c5-0182-4e5d-9f90-2743707aaa8c
# current doc id: ff645876-d4d9-4cdb-930f-ae769348c2ca
# current doc id: 1923a294-9637-4b10-ae80-ca8cc47342d0
# current doc id: 7fd8c9a6-1459-4b29-8acf-66dea2b741ad
# current doc id: 5b0960c3-1a53-4f58-9535-a0f0a363f6ed
# current doc id: b061f9ee-5988-435a-9407-92097808da79
# current doc id: 6aad2bc8-7330-4ae0-abbd-5145ed96b4af
# current doc id: 925b6177-2314-4527-9f0a-166b84cb1fa6
# current doc id: 54477a2a-2e20-4700-afab-3fb5434130e0
# current doc id: d1068e86-94db-482a-b768-2b8afe6b8718
# current doc id: 93f77118-4952-41cd-a800-fccb8f59cd11
# current doc id: 802aa3be-cea7-43c4-a21d-3a655e014aa8
# current doc id: ad53d383-6cf2-452e-9827-50b261cfbc01
# current doc id: 0ce0c710-ffd3-4c8c-a0df-241054dde008
# current doc id: 523b6df1-8846-4a84-8c0f-2c8eb5a96843
# current doc id: b9432e88-bd77-45eb-84c0-8ba46ed958e9
# current doc id: 7649531a-a2f6-457f-8915-3f4d55aafe52
# current doc id: 353d3032-81de-4fb1-87a2-fd705fcfe6d0
# current doc id: 346979e1-a0fd-438d-b954-3e189aad1ad8
# current doc id: e7583eba-1a53-4141-8b10-1d88a72ccd96
# current doc id: 81a93da8-a3f4-4bfc-8bbc-696187356758
# current doc id: a41d58fd-463d-489d-bb26-4e41de5294b5
# current doc id: 0a908361-bf78-4b87-8ccd-6b1febca96ee
# current doc id: 63470442-9ab4-435e-b956-56f119c52db3
# current doc id: 7c5c2088-9922-4466-9eb8-3240e4bc52b4
# current doc id: 3f64f73a-3aaa-4028-9201-b57100489613
# current doc id: 80ff955a-effe-45b8-bbb3-82d97da05cef
# current doc id: 71731c3b-8404-4ad8-a434-a791bdca2b51
# current doc id: 5b1275ff-efe9-4174-9a97-1a133facc83c
# current doc id: 6825f923-33ae-48cd-8307-730ebf81e194
# current doc id: b45b402a-3875-4103-89a5-405d8abbe67f
# current doc id: 042e5681-e38e-4c1b-85b4-5062268fe4e9
# current doc id: f7b2e850-f99f-47e6-862f-ecff5b665098
# current doc id: dd5f7f56-69ad-49b8-9a02-06bad534f69b
# current doc id: 3fc8e476-96b8-4b5a-911e-0eccd139b592
# current doc id: d235797e-64f5-4a9a-a13d-8d2bf8d3cba9
# current doc id: 98800201-f7e4-4734-950f-d43a65e2403c
# current doc id: 2bd34e41-8a50-41b4-8306-633f65afb215
# current doc id: 9012899f-23ab-4ba5-a7d0-445865c20998
# current doc id: 857e8afd-d4e4-4ff8-9518-0ffd8d659971
# current doc id: 2ab008ba-a527-4744-8a32-5695aaee82e7
# current doc id: a8fbd213-3285-4d8e-8b17-b278140f8484
# current doc id: 931c27f3-edfa-4e54-9d03-6f4627adb473
# current doc id: 50c40fa3-307c-4438-8378-a1e0955fdf96
# current doc id: 51bb6392-7454-4b3c-a5a4-e084764f4df8
# current doc id: 0b6adfdc-27ad-42d2-ab24-537c30befa21
# current doc id: 4fd4aa6b-3a9a-42aa-9beb-201fb8754bc5
# current doc id: 4cd34024-8c9b-445b-8b98-e4c4171c03cd
# current doc id: f19b3fc1-a9c1-420f-90ab-f94204e9e798
# current doc id: 54ae50e4-fac2-4b05-b1f9-edf0a277a574
# current doc id: f4b84bc1-123d-4a40-9146-faa88d71fab0
# current doc id: d33b0f46-388f-4f8d-b24b-baf56270b6dd
# current doc id: 57c16e03-abbd-4f99-bbea-2a6f4fee603f
# current doc id: 1c63c110-70ee-4554-9f6d-dafc6e769ebe
# current doc id: 1a6e4bd5-e38f-45b9-937a-b352444aa9b4
# current doc id: ea8fdb1d-aadd-4afa-b5d3-752d64c308e6
# current doc id: f53a53b2-900c-4762-8b68-06230633d220
# current doc id: a487f4fc-50cd-473c-a1a5-01156e37f145
# current doc id: 62db26e7-754a-42dc-8970-0154df82b92d
# current doc id: b3468ac2-4b5f-4378-908f-ecf65031523f
# current doc id: e9bb47db-6ae9-4993-b400-6a9d03ddd0a1
# current doc id: 75e55218-d1d7-4dd4-a446-0f6166892496
# current doc id: f69a4dfb-9274-4c7b-89ed-c01b326c3ea5
# current doc id: c2b3a713-94cd-40f8-9956-cf91229768bb
# current doc id: 85245655-5bb4-42f7-8019-d3c525bde8fc
# current doc id: 5111db72-eb39-4f72-9177-fcfbbfcb0601
# current doc id: 3c37f956-17ef-4076-8fc8-5f064f201bcb
# current doc id: 6eee0a25-2d4c-43f2-960d-c2deb0e87416
# current doc id: 1be3ce00-9299-4dd4-88b0-9c7c3949f866
# current doc id: e66fce66-9ef0-4294-b91c-616a735a009d
# current doc id: fe81546c-09bf-445f-83d3-a1a6434bf12d
# current doc id: 832397df-0e82-4668-b105-30b8a1b65dcf
# current doc id: 26687459-9d26-41d6-a6a8-0e81978ce5ed
# current doc id: 3ab3909b-02d4-41a4-86f4-fb2b9d9c8a09
# current doc id: 30eddd72-8da0-4048-8968-f0dd21646327
# current doc id: 37d21477-dd3d-4450-a494-46ccb014b230
# current doc id: c4be9edc-5c00-4246-9ffb-3f596fd503d7
# current doc id: 81599515-96f1-48dc-a65e-fc25f564e4cf
# current doc id: 0e9d9bb5-12f2-4046-b721-5147fbd0d5c4
# current doc id: 8ba532f1-6bc7-45cd-a35e-7037a2dbe3be
# current doc id: 0b1f45cb-516c-4c3f-8975-9fbe2a59dc52
# current doc id: 8dc4878a-cb37-44b2-a60d-30d44e777ef8
# current doc id: 089e93ad-25ea-4f99-8f72-adb9b02e599e
# current doc id: 53a23251-9d6e-4a3c-bdfe-5fa67abff934
# current doc id: 134eb94c-7972-476e-866e-244c3e04a32b
# current doc id: d1df4356-a0d9-4a74-914d-98b9d157bc3e
# current doc id: 449ac29c-358a-40ad-903c-6b44c2182fe0
# current doc id: 7770347c-5ba4-4932-9f09-60a3ead26c05
# current doc id: 154eda0e-a0c5-4078-9f39-2efad6d00210
# current doc id: 8a32d242-8d7e-4d6e-962f-ffef79553a89
# current doc id: 71336002-4c77-44e5-bf84-0bc2914ebab9
# current doc id: d450d503-b900-4ae8-9495-0fbfa2fd44c3
# current doc id: 38c5cb4b-37fe-456a-af46-54dd303cd313
# current doc id: c9240901-b21b-44b9-a5ab-90020775c074
# current doc id: 26ee8f33-644f-4d96-b3a9-da3dbf889113
# current doc id: 15aa201c-b02b-4bb6-8a90-92d1abe310d4
# current doc id: 8dc1b351-3844-4166-882f-b7198d82ec67
# current doc id: 856f5ee9-8828-401b-bb84-b23dc77a11a4
# current doc id: 7e113d10-36a7-4281-b431-c226fdff1e59
# current doc id: edfda31f-026b-46a5-ac39-1dcb072f2586
# current doc id: c51d71fe-ccfc-4d59-93a9-242da1eafad7
# current doc id: 56ed63f1-7efb-4e98-96cb-c5dcdd9775c4
# current doc id: 0854b644-43f4-405e-9bd9-b51994e62f22
# current doc id: 4e6e520a-8b73-4515-9a83-dc8f5f9cee87
# current doc id: 1a70c0e7-109f-4faa-89e2-c24bfd9fbf6a
# current doc id: 08aeb822-4a19-4a35-ad35-190138d29797
# current doc id: ff162c25-4cb4-4579-a4de-55329dd5bc68
# current doc id: 181d0647-fc22-4a2f-bbe1-39f880c9a9e7
# current doc id: 54ff50b2-2e9e-429d-916a-fa98ace17d8a
# current doc id: 9656291a-9228-4883-881c-d0f4c63888a9
# current doc id: 35c006b2-fd35-4f4a-b018-19066328f4e6
# current doc id: ac81fa83-9ff0-4f4b-9e46-0e0617b03d35
# current doc id: 62c290f0-b75e-4ccc-b731-c3e5b10c629c
# current doc id: 09fed915-439b-4cd1-a8c5-27494bf3d38d
# current doc id: f7a44fb1-a113-4308-9e2f-340320aaa0c1
# current doc id: ac7a58df-cddb-471b-ab1c-6cfc1d344e00
# current doc id: 362607b3-ed76-4f98-9fd7-0a1067ec2138
# current doc id: d8ca77c0-8228-44f9-9a16-8180616f7755
# current doc id: 6a81777b-68ad-456c-9733-88bfda043146
# current doc id: 10e20bae-19de-42c5-9c77-fb5e2dc3d1d3
# current doc id: 25360b3f-4bfa-4c0e-9647-fe38a8e6c9cd
# current doc id: 711cd460-3deb-4f84-a714-d84c079461bf
# current doc id: 7aff2570-e3dc-4a6d-80f7-4ba8464c3c59
# current doc id: ff47839b-d4d3-4c36-93a3-fc593f38c286
# current doc id: 01bbe7c7-a214-4efa-acbf-678c334edc9a
# current doc id: c1b1d4b3-304c-4249-98a5-95d1337d3e83
# current doc id: 3579dc8b-5bcd-41a6-b10f-a729828dd4c7
# current doc id: b7fbabf7-2400-4102-a536-fd68a3821ffd
# current doc id: c1ef8e3a-f23a-47ec-ab34-5882d4191776
# current doc id: fedbe9be-e7f8-4696-9f7f-17f49bc31fac
# current doc id: 2ffcb0ad-7cae-47bb-b0d5-32ef997e8920
# current doc id: 7fa37fa0-c21b-4350-8e5a-5bbcaf89cd25
# current doc id: f0f81c39-c48b-47bb-98b4-afb4a4fda1d7
# current doc id: 6ca45200-07fd-4ee9-8e64-ac73534cd7a2
# current doc id: f6022b0c-91f6-455d-b724-bd14fb0d0ccc
# current doc id: feb998f8-950c-48d9-bbd1-5ea876128683
# current doc id: 64eef544-975d-4694-8513-efcae7e15278
# current doc id: eaf06795-e4d1-4b6e-bf1d-52ff59f232ec
# current doc id: 0ff4477e-4ca4-4bc1-bf95-53a92c781ff6
# current doc id: 8416d612-a613-4969-b72e-9ac8552e0ef0
# current doc id: 94ba5927-a602-4e33-88d3-905a67183260
# current doc id: 6e33d483-cfe1-4939-bbcd-1caf54a8f70f
# current doc id: 7274005d-c2c6-408f-b6dc-096aad86d6c2
# current doc id: 96288f6c-630f-4ff5-bd3b-5abc5f1181d5
# current doc id: 569a3b3d-1a1b-4f66-adc0-3b8b6dd6d750
# current doc id: 5f588269-40b3-40f1-a883-bcba28a37d36
# current doc id: 0e186fe3-4713-4e74-8f7b-87a76b88af7e
# current doc id: db31acd1-9962-4917-839d-a59c9fc5886f
# current doc id: b8e6297e-799a-4e8f-93c5-b1e13c25d9a5
# current doc id: 3f35e60e-95c0-490e-bc95-c1d348cebee3
# current doc id: f594ab4b-62a7-41fc-a912-e6057027e3a1
# current doc id: d40ee4e2-49ee-4485-903f-83a480e9544a
# current doc id: fcaf3a88-be70-4e6a-a235-fd351dec3a5e
# current doc id: d67bb4a4-84ec-4815-b8a7-7e4291305664
# current doc id: 670482cf-ce2d-4a72-91ed-a4ae4d22c08c
# current doc id: 3b084870-5365-497d-9024-1e7553b59d74
# current doc id: a61a5207-edfc-48e2-9680-c368211c209e
# current doc id: 7d4f8bf1-151a-42a9-b2b9-81728287e134
# current doc id: ec9cae8e-6bda-49a5-80e5-9f56d957334b
# current doc id: 2d43bfd6-bbba-4252-978e-fd0322f34663
# current doc id: b0b2ef0d-c770-47d2-926f-7693148c73fd
# current doc id: 420a0b12-ba56-4bf1-836d-1b0afa16f9c3
# current doc id: 0fa17aeb-11fc-4af6-9a56-3a0f3920c146
# current doc id: 854e76d5-6c52-4f11-b9c2-0e787ba0ebd8
# current doc id: 9f06fab5-b561-4d49-ae21-260910b75419
# current doc id: 1af34f7e-56ef-4d94-9617-7377351b36a1
# current doc id: 970b3789-a69e-4880-83d2-c714e7915a96
# current doc id: 60e690d1-95bd-4cbd-bf8f-4d601963168f
# current doc id: a944b554-4f62-4b15-bfca-d93fc7907528
# current doc id: b1db40d7-fe95-4457-9ba2-eb009722795a
# current doc id: 9a02cc0c-aebc-46b7-b375-19f4b4390907
# current doc id: 03ac203e-38f5-43e6-a6d1-140619d59aa8
# current doc id: fd3b412a-3e44-4273-8c49-550a2148328f
# current doc id: 8bf23d7d-9cc1-473f-88c7-eda7368b3c96
# current doc id: 668b097e-debc-45e3-9b50-7b3526dc003c
# current doc id: 7a5c5c8a-ee6d-46dd-9681-406e91ff0807
# current doc id: 4fb959bc-f723-452d-ba09-8aca8a3cb2ce
# current doc id: de55a3cc-096d-446e-93f0-b5b2414de3f8
# current doc id: b7119924-49f2-4eb5-a005-25b70afa8814
# current doc id: e449a180-1f5c-4205-8305-14590beb4e91
# current doc id: d46ef96b-32da-4009-92e5-8c1f76fa35be
# current doc id: e90b074f-e7eb-42cc-9843-ac85d5322bb8
# current doc id: e82e2ef6-9e1d-485f-93da-f2971941f36b
# current doc id: d5d57657-c9ed-4a3e-ad78-1462d375c9fd
# current doc id: ab18f217-b29c-432f-8f4b-dd9eb01e98b0
# current doc id: d6d1799b-d07d-4e86-b498-e8fc89663b62
# current doc id: 67e0d2b4-17bc-46f0-978f-8daf97e6947a
# current doc id: 97e0f41e-b4dd-48d9-8064-7c9672a8367c
# current doc id: 6d0cad34-1519-405d-8c13-c1b76f39c3df
# current doc id: 3faaeb03-b935-4060-8611-35408b341e1b
# current doc id: 4eadc894-0ec0-4376-9580-3f4dc82ef3f9
# current doc id: 594e2f6f-1d9b-44d0-a9b0-16983e30bb91
# current doc id: 1d498742-c15d-424f-af72-56ffdba10cf3
# current doc id: 9f6296ef-1e56-4c7d-8fcf-5f83f193b7fc
# current doc id: e9ec3fff-22a4-41de-a1dd-186adfc12521
# current doc id: 913b265c-9aa5-4218-a874-28c01b2d087d
# current doc id: d59c98ca-8bfc-442e-96ac-f2555a285fa4
# current doc id: 2adb2954-1eeb-422a-b0d6-650a4a4c52a2
# current doc id: 4e657212-cd0b-4197-96fc-8df69532073d
# current doc id: df8957ca-6841-4f18-b979-9e53c3ed0504
# current doc id: 92b521ca-305b-4012-a82a-58860bb1bc18
# current doc id: 16af4e44-9303-4c3a-9df7-01cea4ddbb1d
# current doc id: 0824741d-71b8-4be6-b828-440922d6d77d
# current doc id: 8ed851ca-8a9a-4563-a795-af3c1ff2d210
# current doc id: c14ab4a2-914d-4d54-b79a-e03815323687
# current doc id: bcdf0bdd-6ff0-4a38-955a-db6386e98963
# current doc id: 9feb460d-553e-46c2-ba64-fc81092cc857
# current doc id: e02f705a-aff4-45fc-8cfc-c1c31d75a1f4
# current doc id: 459b76dd-aedd-45c8-9259-5cfaba786f23
# current doc id: 6be65ca8-4b40-4140-a145-24409d4b1332
# current doc id: 28c3f4d4-20a2-460f-a596-3441faf8d4f1
# current doc id: 0f36b552-d719-4763-bca8-c58dce259b15
# current doc id: 836ec1db-86dd-45b5-8983-582b8760d750
# current doc id: 58a3794e-4d26-4d34-a0d1-c9f66e2c8215
# current doc id: e49d6931-9318-4d2e-b43c-4e2671e27336
# current doc id: 8cf66a42-735c-492a-a890-d49efb290367
# current doc id: 54d7a8b9-9e56-4af6-91a2-6718e62d061b
# current doc id: ac9b5e7b-631e-4a8f-a906-82330a91ff20
# current doc id: 7e3b9adb-413a-4ecc-b942-e265a3d54074
# current doc id: 04935c0e-df05-4453-9a50-25ec20ea4e1a
# current doc id: 95b44ea0-fed2-4896-90d8-90aaef6ea3cd
# current doc id: 7dc89998-5fa4-49ab-8c0e-c4a1278dcce8
# current doc id: 54da760a-b508-4ecb-9ae2-557ded8de160
# current doc id: 24bed11e-8d3b-4058-8948-61f31c4e7a63
# current doc id: 7bf9b463-6681-43fc-84c7-9d1440e7e49d
# current doc id: 8dc08a3d-2719-42a7-b872-0e810defb13b
# current doc id: 76dc0f5a-b3b4-4471-9a75-8f1638bf5ff4
# current doc id: d0960205-a166-4113-96fe-09bce96289c3
# current doc id: 752b776e-686c-42a4-83dc-61ac36b80593
# current doc id: 19e49966-e92f-4986-98bd-e23e92033875
# current doc id: 196a5855-e4fa-487a-b54f-5485255c7cdf
# current doc id: c2277b63-089f-4ad6-9bc9-51fafaf0762c
# current doc id: dcf86303-6570-4d13-9174-fc31b9db1fe3
# current doc id: 869d6c25-16b9-4318-b5a6-759ef8ad26e3
# current doc id: 4e0dbada-6af5-4bc2-93c9-38eb47af0b3d
# current doc id: 87a4c24a-0568-42ff-8fd1-f938a7145154
# current doc id: dde9e581-cd7b-4c5a-a5f8-ec60d18ace92
# current doc id: 06e63b33-2a9b-4b84-9bf0-7e9175bbfd4e
# current doc id: dab7bfac-e5f8-48a9-bb29-397aa208ffa2
# current doc id: a2826763-1195-41e9-a963-f6369ae85756
# current doc id: 37a933a7-4365-452c-a034-06d62f7a0088
# current doc id: f7f699ac-efaf-428b-82f3-a451632f1d80
# current doc id: 2526b9d9-c03c-4585-a094-e24a9a390932
# current doc id: e9027d59-547f-4bd5-89fc-7e1c4b73d0d1
# current doc id: 437aa200-bdd4-4701-892b-42b1e81648cb
# current doc id: d62d815a-f79a-4e00-91ac-c474f47322f8
# current doc id: 10dcfd27-f7c8-44ec-bfaf-61a1467ecd8c
# current doc id: f54e5fdb-f6ff-45a6-9c2a-286a85f2f16e
# current doc id: 3911d2f2-c069-44c3-a55c-d2df0c8a41e2
# current doc id: 44ceeaf3-79a9-4e99-9761-b5ce0ac076ca
# current doc id: ee416fe5-fef9-4915-8b60-78f26410b69a
# current doc id: 76d5daab-0aa2-4bcd-94b6-1271cd53c0e3
# current doc id: 1dec0da2-52b3-45bf-afab-53315237be2c
# current doc id: 8e2e68b0-0c95-414b-b482-21d2172985f6
# current doc id: 46cbf57d-0022-4d0e-b51a-0705e0e04aa7
# current doc id: a6bb914a-461c-4af3-a235-a35eb6b70319
# current doc id: aaf1f0a5-6c68-4649-9154-afa922820d94
# current doc id: b5c7e039-d75c-4544-8326-4aeab436e483
# current doc id: 49a73b69-b739-416e-9c4d-6f2d557e9c03
# current doc id: a7336f07-ad62-4789-874e-55d140390254
# current doc id: 084efd05-8c9b-448c-8307-8414f4c46aea
# current doc id: 59af314a-4393-4f7a-823c-f5b01c3075de
# current doc id: 12897e78-bc3a-4be0-bc7a-14a6e2ec8c73
# current doc id: 072b8910-ff45-4d54-b6cb-156116d5d747
# current doc id: e658443a-8c5e-4648-a363-c1f20feafeff
# current doc id: bbce1af2-9f63-47ca-a209-4bf891a9c28f
# current doc id: 2317d443-9bc8-4d65-ae37-c756a91d966f
# current doc id: 3f8da366-0b6b-443e-81d4-aadfe6888f8b
# current doc id: 4d0d4728-c3b7-4c21-ba30-03b8865c71ae
# current doc id: 048f1629-8cc3-4c3b-a311-c3b7509a741a
# current doc id: a006c34c-da13-441e-b8f1-7404329d5752
# current doc id: c26d342a-3758-4408-8ffe-50d15de476c2
# current doc id: 09880e80-7a17-487c-9b17-4c749dc9ee23
# current doc id: d3f778b6-aaec-4a9c-bb38-711f7335d086
# current doc id: 5bac6f12-197f-42c9-813b-1df0fff28e7c
# current doc id: b19e5970-64a0-491b-a48b-fa35baff44eb
# current doc id: 6aa6be5f-0ae2-4559-89df-2f411f2b1dd0
# current doc id: 8ea4acf1-ac71-4e07-aeb9-edfd06d20d91
# current doc id: 5fb5f2cd-3e2a-4c6e-b6c1-4e877eb3c1bd
# current doc id: f26d3d57-af3b-4dbb-8cb6-072eb455cf15
# current doc id: 64c2dcd6-f4d7-40f2-b656-c2ba704506c8
# current doc id: c7111a0d-fbba-4d9b-b3fd-39e227774270
# current doc id: 1bcc3304-add3-4b8f-beb5-226f545771e0
# current doc id: 0efa1507-7336-4337-b9eb-18d7a13d0d18
# current doc id: 98ea18eb-0c40-4cbc-afcf-17270cbe059e
# current doc id: b65b686a-9479-46e6-bf9e-5d3f55fbbba8
# current doc id: 3e1d2068-82e8-4140-9d13-43a3bc255b03
# current doc id: 7536b996-8b1b-4df2-b052-77681314091a
# current doc id: 4dcd2d97-2521-4c7e-b5da-d2d4e1af4434
# current doc id: 04640dbf-d234-41a6-8b25-8f7c0e01a230
# current doc id: 69809742-7f26-4f33-8817-f85ed120ef06
# current doc id: ad78db18-6cd2-41b2-8e09-b2d03af1bd11
# current doc id: 959b1952-0e32-4169-bd24-61300b3b6e1f
# current doc id: b734bd54-e2ba-44f6-b3da-68f8410ad7c0
# current doc id: b01db377-2b76-4d9b-a8ae-b1c749e328b9
# current doc id: 909af9e8-16e3-491e-94a0-c4b1f01d893e
# current doc id: a756a45b-0f3a-4d3b-aca0-8eb132df7987
# current doc id: 8d128790-e035-4160-957f-0d8d0100035b
# current doc id: f5691242-9acb-4144-a532-dd38385db5b8
# current doc id: c9f79765-8e30-4d97-8d88-18915403b74f
# current doc id: bfca0426-2889-4a61-8673-363a136c43c3
# current doc id: 057d607d-603a-4f20-91b7-8125b8006536
# current doc id: 14ca41da-eb34-4e7d-80fc-88dacc5fa2ae
# current doc id: 95b727b1-e216-4e93-8e44-a5722edc16d3
# current doc id: a277c00b-df45-4788-8e1d-364bcd1694cb
# current doc id: a114e445-78f0-4b15-903c-772312c04a45
# current doc id: 0e2773fb-9d06-4a4f-a5a4-e3f1bf84722b
# current doc id: 8afd60ea-a0e6-4a61-9385-0aa92ffb4e4f
# current doc id: 624e047f-0eab-4ff1-aaa1-a70b49dae775
# current doc id: 7495e854-bd95-4ad9-b9d4-8d1275248442
# current doc id: 2c9748df-b590-4a01-aed3-e6b564e0707d
# current doc id: b6115e7c-b3a0-4e36-ac5e-c83277f4b0ea
# current doc id: f520b05b-199f-48b5-bf3c-68e3dd488450
# current doc id: 0fb5647a-987e-47fe-bc45-f842f2761715
# current doc id: db05d2df-fb6f-4841-b576-fc19c9164cf9
# current doc id: 809871d8-2960-4fde-86f3-0425ab39fef2
# current doc id: c9e95140-130d-499c-a6aa-6e49b580efb7
# current doc id: 3f66ede8-01c0-41e6-be39-7423ba76a39c
# current doc id: e8ee17a4-d762-48cd-b35e-348fca71e3f8
# current doc id: b77b3bbc-0dde-4ec3-901e-c9c9018dfa54
# current doc id: 7fcaf760-0455-4b56-9bef-214f39bf1d2e
# current doc id: 6a778383-448e-444e-9cdd-19e8cc1ca681
# current doc id: 4cfc2fc4-5cf0-4f95-86fa-98e346f48e73
# current doc id: a9b09fd3-f0aa-4ddb-91c8-6af7771bbe73
# current doc id: f2ece794-5059-4475-8e5b-018b25448d4e
# current doc id: f7d3b72d-8ee1-41cb-a834-ed31ece877ed
# current doc id: c54c9455-0c24-4e4c-9f7f-c462b6dd03c1
# current doc id: 2b876e20-332d-4629-b666-350d4918f641
# current doc id: 4e8363d9-a9b3-425b-82c7-b4882135abca
# current doc id: d27cc1ac-5a4c-4873-acd9-887872d36dd2
# current doc id: 822f7dde-d991-4075-a504-ed2069358b7b
# current doc id: 3f14a66e-f145-4129-b209-654f65a63abc
# current doc id: 8530bef3-3fee-499a-9aae-30fc055cc1cd
# current doc id: b1497567-6e72-4b4b-ac18-1f06ce548f4c
# current doc id: def8fa0e-115d-4b00-80ca-5ea31949219d
# current doc id: 34c6aea7-b763-4e9f-bbfb-ec946a7eeb2c
# current doc id: b32a44dc-58d3-4da4-a21d-5c018b01e5c4
# current doc id: 944c64c7-f667-4157-a52e-285c1fbb557a
# current doc id: 01ed4eec-1a1a-462b-9a59-f5a2c4368c25
# current doc id: ba9512ef-dec4-4e7a-934f-31053cd94e38
# current doc id: 7601ba27-3fae-4e1b-978f-14b78a0df7d8
# current doc id: fed4adbc-1236-41bf-a680-0472c7357f31
# current doc id: fd8eed09-92e4-43db-975c-d48ec28bba3e
# current doc id: 8ba0ffe5-de6d-4bfb-b465-416d3e989476
# current doc id: e896b600-22bc-41bc-857c-b606f66440ea
# current doc id: 38f935b4-e8d3-46a3-afa9-3fa64d93aee9
# current doc id: 0411f082-8928-40fb-98e7-933b24945c27
# current doc id: d758e5cd-425b-4c73-a975-20c85f69f1db
# current doc id: ef8fd223-58d0-4c56-836e-0d7c39af41e5
# current doc id: 5373bbf7-f74d-4ecf-b3a0-ca2600bdfacc
# current doc id: 87252a9b-d823-4e2c-8173-6650e35f9660
# current doc id: 7373a9f3-0440-4b5b-bfd7-1847082611ec
# current doc id: c2eab1e6-5e27-4538-972d-67a2f1a18d60
# current doc id: 78086011-a81c-4a62-ab47-a4896b7dce57
# current doc id: 02b54f24-68f9-493f-a469-36884b7749b4
# current doc id: 37e8dcb8-dcb8-448f-b172-5909c70fc5b4
# current doc id: 64361adc-f195-4684-a8ef-57c0b89abffb
# current doc id: f35a0ccb-e991-4b6b-aedc-da93bb748030
# current doc id: f5e60501-8c8c-40ce-a14c-cfec20153d39
# current doc id: cd218222-c16d-4561-a45d-63a5fc58ee48
# current doc id: e76121e2-5b02-489d-843d-e25e070ffa86
# current doc id: 6b2fe182-6db1-4848-bda5-fe5aa702a4b6
# current doc id: d5084c7e-e090-4113-9413-7bbdf18068fe
# current doc id: 0d3e9217-58d6-49ed-9e89-3ea8ca32bd2a
# current doc id: e9625257-c1e9-4932-9390-51ce67268044
# current doc id: c1623f30-e842-48d1-9e17-f0f8558f1364
# current doc id: d80f0d6c-5a25-4880-b8da-da85d8ab2d26
# current doc id: 8e943849-ac60-4bb1-abb4-509978e4bfa7
# current doc id: 20edc80c-bbc3-4fb3-adc2-4b606d101ae4
# current doc id: a4a3efbd-1d5e-4742-b032-93a6b30642a5
# current doc id: 12175f82-2624-405a-9ea7-b293a3223fde
# current doc id: 34093f25-ad05-40e8-86aa-9ab8b17f0269
# current doc id: bc3b94b5-8ea8-4d68-afff-1c91d290d3b8
# current doc id: 569fe9ea-6bf6-4fb3-ae01-af7274f05ded
# current doc id: e31682be-ade7-4b80-89bc-92b142757d2b
# current doc id: c853b672-7d46-4ead-96a7-af0bec9e3c04
# current doc id: 43e3c377-0796-4ace-815a-7c918023d894
# current doc id: 85284b68-f029-461d-8388-8b8a039306d2
# current doc id: c8434f01-7bf0-4a75-a33c-76b3d78505ef
# current doc id: 43290f41-cba5-45f4-a806-417e7424de7b
# current doc id: 2db42a53-64fe-4807-ac87-4a257940a268
# current doc id: d91b3736-a58c-4f77-9bdf-28397ba1263c
# current doc id: dce0af2f-ff87-44df-99e5-82684d791cd7
# current doc id: c194372e-d258-4e8b-98a9-7d207c2dbab9
# current doc id: 606f5468-2d79-419b-ae76-15ffd9bc08bf
# current doc id: 62b29d91-6446-478d-8969-39f1493bb70a
# current doc id: 66c55cdb-0611-4516-8a1a-d796ca652b8b
# current doc id: 9a08bc17-d8a0-4732-ae0e-1de3286c3a1b
# current doc id: 450e1ef1-2194-4f9d-93cc-6e347929436d
# current doc id: 05e9e36e-7481-4ee8-9512-3a8f45158cf5
# current doc id: 65677c7a-3811-4df4-bf78-885a47d30124
# current doc id: fa78fffb-a6cb-4fcb-9cc8-7b18e0eab939
# current doc id: bf004303-dc20-44d6-b7f2-c9a8831d4600
# current doc id: aed807f3-9d89-4ec2-8c8c-b8c1710cb63e
# current doc id: 4635e6c8-7c5b-4da6-b433-9dfa80132f47
# current doc id: 6f2e9269-027e-4bc4-a820-95417d04b4ec
# current doc id: 9770220e-eefd-4c4f-95c9-c811a86c0c9b
# current doc id: aa238d53-c89f-473b-b2e1-b929f12da221
# current doc id: fc43421c-af9b-4ff7-99c5-3b672e278ae3
# current doc id: 7ddfbed8-66fa-45c7-9042-c921ec48426d
# current doc id: e4c92c2c-f5be-4e83-9e9c-beb212ae9826
# current doc id: 7fac9405-d267-49e3-8ce8-de800ee877d3

# %%
print(response)
# Out:
# ```python
# from typing import List
#
#
# def has_close_elements(numbers: List[float], threshold: float) -> bool:
#     for idx, elem in enumerate(numbers):
#         for idx2, elem2 in enumerate(numbers):
#             if idx != idx2:
#                 distance = abs(elem - elem2)
#                 if distance < threshold:
#                     return True
#
#     return False
# ```

# %% [markdown]
# ## Tree Index

# %%
from llama_index.core import TreeIndex
tree_index = TreeIndex.from_documents(code_documents)
tree_index_query_engine = tree_index.as_query_engine()

response = tree_index_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# ```python
# from typing import List
#
#
# def has_close_elements(numbers: List[float], threshold: float) -> bool:
#     for idx, elem in enumerate(numbers):
#         for idx2, elem2 in enumerate(numbers):
#             if idx != idx2:
#                 distance = abs(elem - elem2)
#                 if distance < threshold:
#                     return True
#
#     return False
# ```

# %% [markdown]
# ## Keyword Table Index

# %%
from llama_index.core import KeywordTableIndex
keyword_table_index = KeywordTableIndex.from_documents(code_documents)
keyword_table_index_query_engine = keyword_table_index.as_query_engine()

response = keyword_table_index_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# ```python
# def has_close_elements(numbers: List[float], threshold: float) -> bool:
#     for idx, elem in enumerate(numbers):
#         for idx2, elem2 in enumerate(numbers):
#             if idx != idx2:
#                 distance = abs(elem - elem2)
#                 if distance < threshold:
#                     return True
#     return False
# ```

# %% [markdown]
# ## Property Graph Index

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import PropertyGraphIndex
property_graph_index = PropertyGraphIndex.from_documents(code_documents,)
property_graph_index_query_engine = property_graph_index.as_query_engine()

response = property_graph_index_query_engine.query(
    test_query
)

# %%
print(response)
# Out:
# def has_close_elements(numbers: List[float], threshold: float) -> bool:
#     for i in range(len(numbers)):
#         for j in range(i+1, len(numbers)):
#             if abs(numbers[i] - numbers[j]) < threshold:
#                 return True
#     return False

# %% [markdown]
# # Predictions (Not in Use)
#
# **NOTE**: The rest of the notebook illustrates how to manually perform predictions and subsequent evaluations for demonstrative purposes. Alternatively you can use the `RagEvaluatorPack` that will take care of predicting and evaluating using a RAG system that you would have provided.

# %%
from llama_index.core import VectorStoreIndex

# a basic RAG pipeline, uses defaults
index = VectorStoreIndex.from_documents(documents=documents)
query_engine = index.as_query_engine()

# %% [markdown]
# You can now create predictions and perform evaluation manually or download the `PredictAndEvaluatePack` to do this for you in a single line of code.

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
# manually
prediction_dataset = await essay_dataset.amake_predictions_with(
    query_engine=query_engine, show_progress=True
)

# %%
prediction_dataset.to_pandas()[:5]

# %% [markdown]
# # Evaluation (Not in Use)
#
# Now that we have our predictions, we can perform evaluations on two dimensions:
#
# 1. The generated response: how well the predicted response matches the reference answer.
# 2. The retrieved contexts: how well the retrieved contexts for the prediction match the reference contexts.
#
# NOTE: For retrieved contexts, we are unable to use standard retrieval metrics such as `hit rate` and `mean reciproccal rank` due to the fact that doing so requires we have the same index that was used to generate the ground truth data. But, it is not necessary for a `LabelledRagDataset` to be even created by an index. As such, we will use `semantic similarity` between the prediction's contexts and the reference contexts as a measure of goodness.

# %%
import tqdm

# %% [markdown]
# For evaluating the response, we will use the LLM-As-A-Judge pattern. Specifically, we will use `CorrectnessEvaluator`, `FaithfulnessEvaluator` and `RelevancyEvaluator`.
#
# For evaluating the goodness of the retrieved contexts we will use `SemanticSimilarityEvaluator`.

# %%
# instantiate the gpt-4 judge
from llama_index.llms.openai import OpenAI
from llama_index.core.evaluation import (
    CorrectnessEvaluator,
    FaithfulnessEvaluator,
    RelevancyEvaluator,
    SemanticSimilarityEvaluator,
)

judges = {}

judges["correctness"] = CorrectnessEvaluator(
    llm=OpenAI(temperature=0, model="gpt-4"),
)

judges["relevancy"] = RelevancyEvaluator(
    llm=OpenAI(temperature=0, model="gpt-4"),
)

judges["faithfulness"] = FaithfulnessEvaluator(
    llm=OpenAI(temperature=0, model="gpt-4"),
)

judges["semantic_similarity"] = SemanticSimilarityEvaluator()

# %% [markdown]
# Loop through the (`labelled_example`, `prediction`) pais and perform the evaluations on each of them individually.

# %%
evals = {
    "correctness": [],
    "relevancy": [],
    "faithfulness": [],
    "context_similarity": [],
}

for example, prediction in tqdm.tqdm(
    zip(essay_dataset.examples, prediction_dataset.predictions)
):
    correctness_result = judges["correctness"].evaluate(
        query=example.query,
        response=prediction.response,
        reference=example.reference_answer,
    )

    relevancy_result = judges["relevancy"].evaluate(
        query=example.query,
        response=prediction.response,
        contexts=prediction.contexts,
    )

    faithfulness_result = judges["faithfulness"].evaluate(
        query=example.query,
        response=prediction.response,
        contexts=prediction.contexts,
    )

    semantic_similarity_result = judges["semantic_similarity"].evaluate(
        query=example.query,
        response="\n".join(prediction.contexts),
        reference="\n".join(example.reference_contexts),
    )

    evals["correctness"].append(correctness_result)
    evals["relevancy"].append(relevancy_result)
    evals["faithfulness"].append(faithfulness_result)
    evals["context_similarity"].append(semantic_similarity_result)

# %%
import json

# saving evaluations
evaluations_objects = {
    "context_similarity": [e.dict() for e in evals["context_similarity"]],
    "correctness": [e.dict() for e in evals["correctness"]],
    "faithfulness": [e.dict() for e in evals["faithfulness"]],
    "relevancy": [e.dict() for e in evals["relevancy"]],
}

with open("evaluations.json", "w") as json_file:
    json.dump(evaluations_objects, json_file)

# %% [markdown]
# Now, we can use our notebook utility functions to view these evaluations.

# %%
import pandas as pd
from llama_index.core.evaluation.notebook_utils import get_eval_results_df

deep_eval_df, mean_correctness_df = get_eval_results_df(
    ["base_rag"] * len(evals["correctness"]),
    evals["correctness"],
    metric="correctness",
)
deep_eval_df, mean_relevancy_df = get_eval_results_df(
    ["base_rag"] * len(evals["relevancy"]),
    evals["relevancy"],
    metric="relevancy",
)
_, mean_faithfulness_df = get_eval_results_df(
    ["base_rag"] * len(evals["faithfulness"]),
    evals["faithfulness"],
    metric="faithfulness",
)
_, mean_context_similarity_df = get_eval_results_df(
    ["base_rag"] * len(evals["context_similarity"]),
    evals["context_similarity"],
    metric="context_similarity",
)

mean_scores_df = pd.concat(
    [
        mean_correctness_df.reset_index(),
        mean_relevancy_df.reset_index(),
        mean_faithfulness_df.reset_index(),
        mean_context_similarity_df.reset_index(),
    ],
    axis=0,
    ignore_index=True,
)
mean_scores_df = mean_scores_df.set_index("index")
mean_scores_df.index = mean_scores_df.index.set_names(["metrics"])

# %%
mean_scores_df

# %% [markdown]
# # Note: RagEvaluatorPack
#
# On this toy example, we see that the basic RAG pipeline performs quite well against the evaluation benchmark (`essay_dataset`)! For completeness, to perform the above steps instead by using the `RagEvaluatorPack`, use the code provided below:

# %%
from llama_index.core.llama_pack import download_llama_pack

RagEvaluatorPack = download_llama_pack("RagEvaluatorPack", "./pack")
rag_evaluator = RagEvaluatorPack(
    query_engine=query_engine, essay_dataset=essay_dataset, show_progress=True
)

############################################################################
# NOTE: If have a lower tier subscription for OpenAI API like Usage Tier 1 #
# then you'll need to use different batch_size and sleep_time_in_seconds.  #
# For Usage Tier 1, settings that seemed to work well were batch_size=5,   #
# and sleep_time_in_seconds=15 (as of December 2023.)                      #
############################################################################

benchmark_df = await rag_evaluator_pack.arun(
    batch_size=20,  # batches the number of openai api calls to make
    sleep_time_in_seconds=1,  # seconds to sleep before making an api call
)
